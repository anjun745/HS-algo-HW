# %% [markdown]
# # Defeating Word GOLF with Graph Search in $O(m+n)$ time
#
# You may remember playing Word Golf in Comp Sci I.  Now we are going to get serious about solving this problem using Graph Search.
#
# Here are the rules of **Word Golf**.  You are given two words of equal length, and you must find a path between those two words by only changing a single letter at a time to create a path of **real words** from the first word to the second.
#
# For example:  If you are given these two words: **CARS** and **DRAT**, you might find a path like this:
#
#     CARS -> CART -> DART -> DAFT -> DEFT -> DEBT -> DEET -> BEET -> BEAT -> BRAT -> DRAT

# %% [markdown]
# ## Steps for a Word Golf Assignment (DAY 1)
#
# ### 1. Write a function
# * create a function called `one_away` that takes in 2 words and returns True if they are one word_golf move away and False otherwise

# %%
def one_away(word1, word2):
    '''
    determines if 2 words of the same length is 1 away
    inputs: 2 words
    outputs: whether or not the words are 1 away
    '''
    if word1 == word2:
        return False
    if len(word1) == len(word2):
        dif = False
        for i in range(len(word1)):
            # using the dif variable as an extra strike before the out
            if word1[i] != word2[i]:
                if dif:
                    return False
                dif = True
        return True
    return False

# %%
s = 'CARS -> CART -> DART -> DAFT -> DEFT -> DEBT -> DEET -> BEET -> BEAT -> BRAT -> DRAT'.split(' -> ')
for d in s:
    print(one_away(s[0], d), d)
for d in range(len(s)-1):
    print(one_away(s[d], s[d+1]), s[d], s[d+1])
# Out:
# False CARS
# True CART
# False DART
# False DAFT
# False DEFT
# False DEBT
# False DEET
# False BEET
# False BEAT
# False BRAT
# False DRAT
# True CARS CART
# True CART DART
# True DART DAFT
# True DAFT DEFT
# True DEFT DEBT
# True DEBT DEET
# True DEET BEET
# True BEET BEAT
# True BEAT BRAT
# True BRAT DRAT

# %% [markdown]
# ### 2. Create the Adjacency List Graph
#
# * To facilitate solving Word Golf, we are going to create a **Graph** data structure where each word represents a **node** on the graph and is connected via **edges** to each word that is "one-away" from it.
# * We will be using a very simple Adjacency List to represent this graph
# * To review Adjacency Lists and basic Graph vocabulary, watch this [Tim Roughgarden Video on Graph Representations](https://youtu.be/b-Mfu8dPv9U) (14 Minutes)
# * using the `sowpods.txt` scrabble word file, create a python dictionary with keys as all the 4 letter words and a list of all the one_away words as the values.  This will require O(n^2) time to process so you might want to add some sort of counter to your code to track it's progress.  It will look something like this:
#
# ```python
# four_letter_graph = {'BEAD': ['BEAK', 'BEAM', 'BEAN', 'BEAR', 'BEAT', 'BEAU'],
#                      'BEAK': ['BEAD', 'BEAM', 'BEAN', 'BEAR', 'BEAT', 'BEAU', 'BECK'],
#                      'BEAM': ['BEAD', 'BEAK', 'BEAN', 'BEAR', 'BEAT']}
# ```
#
# Here's a reminder on how to read a file in Python in case you're rusty on this:
#
# ```python
# # read the words in from a file and add the 2 letter words to a list
# words2 = []
# with open("sowpods.txt","r") as sowpods:
#     for line in sowpods:
#         word = line.strip().upper()
#         if len(word) == 2:
#             words2.append(word)
# ```

# %%
l, c, w = {}, 0, len('hello')
print(l, c, w)
# Out:
# {} 0 5

# %%
def create_dictionary_graph(word_length=4):
    '''reads the word_length words from the sowpods.txt file and 
    return an adjacency list dictionary of the form
    key: word, value: list of words that are one_away from that word'''
    with open("sowpods.txt","r") as sowpods:
        # may not run as fast, but looked fancier, don't flame me please
        words = [l.strip().upper() for l in sowpods if len(l.strip().upper()) == word_length]
    letter_graph, count, length = {}, 0, len(words)
    for w in words:
        letter_graph[w] = []
        for o in words:
            if one_away(w, o):
                letter_graph[w].append(o)
        count += 1
        if not count%500:
            print(count/length)
    return letter_graph


z = create_dictionary_graph()
for i in z:
    print(i, z[i])
# Out:
# 0.09167583425009168
# 0.18335166850018336
# 0.27502750275027504
# 0.3667033370003667
# 0.4583791712504584
# 0.5500550055005501
# 0.6417308397506417
# 0.7334066740007334
# 0.8250825082508251
# 0.9167583425009168
# AAHS ['AALS', 'DAHS', 'FAHS', 'HAHS', 'LAHS', 'PAHS', 'RAHS', 'YAHS']
# AALS ['AAHS', 'AILS', 'ALLS', 'AWLS', 'BALS', 'DALS', 'GALS', 'MALS', 'PALS', 'SALS']
# ABAC ['ABAS']
# ABAS ['ABAC', 'ABBS', 'ABOS', 'ABYS', 'AGAS', 'AIAS', 'ALAS', 'AMAS', 'ANAS', 'AVAS', 'OBAS']
# ABBA ['ABBE', 'ABBS', 'ALBA', 'ARBA']
# ABBE ['ABBA', 'ABBS', 'ABLE', 'ABYE', 'ALBE']
# ABBS ['ABAS', 'ABBA', 'ABBE', 'ABOS', 'ABYS', 'ALBS', 'ARBS', 'EBBS']
# ABED ['ABET', 'ABID', 'ACED', 'AGED', 'AHED', 'AKED', 'APED', 'ARED', 'AWED', 'AXED']
# ABET ['ABED', 'ABUT', 'ARET', 'YBET']
# ABID ['ABED', 'ACID', 'AMID', 'ARID', 'AVID']
# ABLE ['ABBE', 'ABLY', 'ABYE', 'ARLE', 'AXLE']
# ABLY ['ABLE', 'AGLY', 'ALLY']
# ABOS ['ABAS', 'ABBS', 'ABYS', 'ADOS', 'APOS', 'AVOS', 'OBOS']
# ABRI []
# ABUT ['ABET']
# ABYE ['ABBE', 'ABLE', 'ABYS']
# ABYS ['ABAS', 'ABBS', 'ABOS', 'ABYE']
# ACAI []
# ACCA ['ACTA']
# ACED ['ABED', 'ACER', 'ACES', 'ACID', 'AGED', 'AHED', 'AKED', 'APED', 'ARED', 'AWED', 'AXED', 'ICED']
# ACER ['ACED', 'ACES', 'AGER', 'APER', 'AVER', 'ICER']
# ACES ['ACED', 'ACER', 'ACTS', 'AGES', 'AKES', 'ALES', 'ANES', 'APES', 'ARES', 'ATES', 'AVES', 'AWES', 'AXES', 'AYES', 'ICES']
# ACHE ['ACHY', 'ACME', 'ACNE', 'ACRE', 'ECHE', 'OCHE']
# ACHY ['ACHE', 'ASHY']
# ACID ['ABID', 'ACED', 'AMID', 'ARID', 'AVID']
# ACME ['ACHE', 'ACNE', 'ACRE', 'ALME']
# ACNE ['ACHE', 'ACME', 'ACRE', 'AINE', 'AUNE']
# ACRE ['ACHE', 'ACME', 'ACNE', 'AYRE']
# ACTA ['ACCA', 'ACTS', 'ANTA', 'OCTA']
# ACTS ['ACES', 'ACTA', 'AITS', 'ALTS', 'ANTS', 'APTS', 'ARTS']
# ACYL ['AMYL', 'ARYL']
# ADAW []
# ADDS ['ADDY', 'ADOS', 'AIDS', 'ANDS', 'ARDS', 'ODDS']
# ADDY ['ADDS', 'ADRY', 'EDDY']
# ADIT ['ALIT', 'EDIT']
# ADOS ['ABOS', 'ADDS', 'APOS', 'AVOS', 'UDOS']
# ADRY ['ADDY', 'AERY', 'AIRY', 'AWRY']
# ADZE []
# AEON ['AGON', 'ANON', 'AXON', 'AZON', 'JEON', 'NEON', 'PEON']
# AERO ['AERY', 'AFRO', 'CERO', 'DERO', 'HERO', 'KERO', 'WERO', 'ZERO']
# AERY ['ADRY', 'AERO', 'AIRY', 'AWRY', 'EERY', 'HERY', 'VERY']
# AESC []
# AFAR ['AGAR', 'AJAR', 'ALAR', 'ARAR', 'ASAR']
# AFFY ['IFFY']
# AFRO ['AERO']
# AGAR ['AFAR', 'AGAS', 'AGER', 'AJAR', 'ALAR', 'ARAR', 'ASAR']
# AGAS ['ABAS', 'AGAR', 'AGES', 'AIAS', 'ALAS', 'AMAS', 'ANAS', 'AVAS']
# AGED ['ABED', 'ACED', 'AGEE', 'AGEN', 'AGER', 'AGES', 'AHED', 'AKED', 'APED', 'ARED', 'AWED', 'AXED']
# AGEE ['AGED', 'AGEN', 'AGER', 'AGES', 'AGUE', 'AJEE', 'AKEE', 'ALEE', 'AWEE', 'OGEE']
# AGEN ['AGED', 'AGEE', 'AGER', 'AGES', 'AGIN', 'AGON', 'AMEN']
# AGER ['ACER', 'AGAR', 'AGED', 'AGEE', 'AGEN', 'AGES', 'APER', 'AVER', 'EGER']
# AGES ['ACES', 'AGAS', 'AGED', 'AGEE', 'AGEN', 'AGER', 'AKES', 'ALES', 'ANES', 'APES', 'ARES', 'ATES', 'AVES', 'AWES', 'AXES', 'AYES']
# AGHA ['AGMA']
# AGIN ['AGEN', 'AGIO', 'AGON', 'AKIN', 'AMIN', 'AYIN']
# AGIO ['AGIN']
# AGLU ['AGLY', 'IGLU']
# AGLY ['ABLY', 'AGLU', 'ALLY', 'UGLY']
# AGMA ['AGHA', 'ALMA', 'ATMA', 'EGMA']
# AGOG ['AGON']
# AGON ['AEON', 'AGEN', 'AGIN', 'AGOG', 'ANON', 'AXON', 'AZON']
# AGUE ['AGEE']
# AHED ['ABED', 'ACED', 'AGED', 'AHEM', 'AKED', 'APED', 'ARED', 'AWED', 'AXED', 'EHED', 'OHED', 'SHED']
# AHEM ['AHED', 'THEM']
# AHIS ['AMIS', 'ANIS', 'ARIS', 'AXIS', 'CHIS', 'GHIS', 'KHIS', 'PHIS', 'THIS']
# AHOY []
# AIAS ['ABAS', 'AGAS', 'AIDS', 'AILS', 'AIMS', 'AINS', 'AIRS', 'AITS', 'ALAS', 'AMAS', 'ANAS', 'AVAS', 'BIAS', 'LIAS', 'PIAS', 'RIAS', 'VIAS']
# AIDE ['AIDS', 'AINE', 'BIDE', 'CIDE', 'EIDE', 'HIDE', 'NIDE', 'RIDE', 'SIDE', 'TIDE', 'VIDE', 'WIDE']
# AIDS ['ADDS', 'AIAS', 'AIDE', 'AILS', 'AIMS', 'AINS', 'AIRS', 'AITS', 'ANDS', 'ARDS', 'BIDS', 'CIDS', 'FIDS', 'GIDS', 'KIDS', 'LIDS', 'MIDS', 'NIDS', 'RIDS', 'TIDS', 'VIDS', 'YIDS']
# AIGA ['ALGA', 'ANGA', 'BIGA', 'GIGA', 'VIGA']
# AILS ['AALS', 'AIAS', 'AIDS', 'AIMS', 'AINS', 'AIRS', 'AITS', 'ALLS', 'AWLS', 'FILS', 'MILS', 'NILS', 'OILS', 'TILS']
# AIMS ['AIAS', 'AIDS', 'AILS', 'AINS', 'AIRS', 'AITS', 'ALMS', 'ARMS', 'DIMS', 'HIMS', 'NIMS', 'RIMS', 'SIMS', 'VIMS']
# AINE ['ACNE', 'AIDE', 'AINS', 'AUNE', 'BINE', 'CINE', 'DINE', 'EINE', 'FINE', 'KINE', 'LINE', 'MINE', 'NINE', 'PINE', 'RINE', 'SINE', 'TINE', 'VINE', 'WINE', 'ZINE']
# AINS ['AIAS', 'AIDS', 'AILS', 'AIMS', 'AINE', 'AIRS', 'AITS', 'ANNS', 'AWNS', 'BINS', 'DINS', 'FINS', 'GINS', 'HINS', 'JINS', 'KINS', 'LINS', 'PINS', 'RINS', 'SINS', 'TINS', 'VINS', 'WINS', 'YINS', 'ZINS']
# AIRN ['AIRS', 'AIRT', 'AIRY', 'FIRN', 'GIRN', 'KIRN', 'PIRN']
# AIRS ['AIAS', 'AIDS', 'AILS', 'AIMS', 'AINS', 'AIRN', 'AIRT', 'AIRY', 'AITS', 'FIRS', 'KIRS', 'MIRS', 'PIRS', 'SIRS']
# AIRT ['AIRN', 'AIRS', 'AIRY', 'DIRT', 'GIRT']
# AIRY ['ADRY', 'AERY', 'AIRN', 'AIRS', 'AIRT', 'AWRY', 'MIRY', 'WIRY']
# AITS ['ACTS', 'AIAS', 'AIDS', 'AILS', 'AIMS', 'AINS', 'AIRS', 'AITU', 'ALTS', 'ANTS', 'APTS', 'ARTS', 'BITS', 'CITS', 'DITS', 'FITS', 'GITS', 'HITS', 'KITS', 'LITS', 'NITS', 'PITS', 'RITS', 'SITS', 'TITS', 'WITS', 'ZITS']
# AITU ['AITS', 'LITU']
# AJAR ['AFAR', 'AGAR', 'ALAR', 'ARAR', 'ASAR']
# AJEE ['AGEE', 'AKEE', 'ALEE', 'AWEE']
# AKED ['ABED', 'ACED', 'AGED', 'AHED', 'AKEE', 'AKES', 'APED', 'ARED', 'AWED', 'AXED', 'EKED']
# AKEE ['AGEE', 'AJEE', 'AKED', 'AKES', 'ALEE', 'AWEE', 'SKEE']
# AKES ['ACES', 'AGES', 'AKED', 'AKEE', 'ALES', 'ANES', 'APES', 'ARES', 'ATES', 'AVES', 'AWES', 'AXES', 'AYES', 'EKES', 'OKES', 'UKES']
# AKIN ['AGIN', 'AMIN', 'AYIN', 'SKIN']
# ALAE ['ALAN', 'ALAP', 'ALAR', 'ALAS', 'ALAY', 'ALBE', 'ALEE', 'ALME', 'ALOE', 'BLAE', 'SLAE']
# ALAN ['ALAE', 'ALAP', 'ALAR', 'ALAS', 'ALAY', 'ANAN', 'AZAN', 'CLAN', 'ELAN', 'FLAN', 'PLAN', 'ULAN']
# ALAP ['ALAE', 'ALAN', 'ALAR', 'ALAS', 'ALAY', 'ATAP', 'CLAP', 'FLAP', 'KLAP', 'PLAP', 'SLAP']
# ALAR ['AFAR', 'AGAR', 'AJAR', 'ALAE', 'ALAN', 'ALAP', 'ALAS', 'ALAY', 'ARAR', 'ASAR']
# ALAS ['ABAS', 'AGAS', 'AIAS', 'ALAE', 'ALAN', 'ALAP', 'ALAR', 'ALAY', 'ALBS', 'ALES', 'ALFS', 'ALLS', 'ALMS', 'ALPS', 'ALTS', 'AMAS', 'ANAS', 'AVAS']
# ALAY ['ALAE', 'ALAN', 'ALAP', 'ALAR', 'ALAS', 'ALKY', 'ALLY', 'APAY', 'AWAY', 'BLAY', 'CLAY', 'FLAY', 'PLAY', 'SLAY']
# ALBA ['ABBA', 'ALBE', 'ALBS', 'ALFA', 'ALGA', 'ALMA', 'ARBA']
# ALBE ['ABBE', 'ALAE', 'ALBA', 'ALBS', 'ALEE', 'ALME', 'ALOE']
# ALBS ['ABBS', 'ALAS', 'ALBA', 'ALBE', 'ALES', 'ALFS', 'ALLS', 'ALMS', 'ALPS', 'ALTS', 'ARBS']
# ALCO ['ALKO', 'ALSO', 'ALTO', 'ARCO']
# ALEC ['ALEE', 'ALEF', 'ALES', 'ALEW']
# ALEE ['AGEE', 'AJEE', 'AKEE', 'ALAE', 'ALBE', 'ALEC', 'ALEF', 'ALES', 'ALEW', 'ALME', 'ALOE', 'AWEE', 'BLEE', 'FLEE', 'GLEE', 'SLEE']
# ALEF ['ALEC', 'ALEE', 'ALES', 'ALEW', 'ALIF', 'CLEF']
# ALES ['ACES', 'AGES', 'AKES', 'ALAS', 'ALBS', 'ALEC', 'ALEE', 'ALEF', 'ALEW', 'ALFS', 'ALLS', 'ALMS', 'ALPS', 'ALTS', 'ANES', 'APES', 'ARES', 'ATES', 'AVES', 'AWES', 'AXES', 'AYES', 'OLES', 'ULES']
# ALEW ['ALEC', 'ALEE', 'ALEF', 'ALES', 'ALOW', 'ANEW', 'AREW', 'BLEW', 'CLEW', 'FLEW', 'PLEW', 'SLEW']
# ALFA ['ALBA', 'ALFS', 'ALGA', 'ALMA']
# ALFS ['ALAS', 'ALBS', 'ALES', 'ALFA', 'ALLS', 'ALMS', 'ALPS', 'ALTS', 'ARFS', 'AUFS', 'ELFS']
# ALGA ['AIGA', 'ALBA', 'ALFA', 'ALMA', 'ANGA']
# ALIF ['ALEF', 'ALIT']
# ALIT ['ADIT', 'ALIF', 'FLIT', 'GLIT', 'SLIT']
# ALKO ['ALCO', 'ALKY', 'ALSO', 'ALTO']
# ALKY ['ALAY', 'ALKO', 'ALLY']
# ALLS ['AALS', 'AILS', 'ALAS', 'ALBS', 'ALES', 'ALFS', 'ALLY', 'ALMS', 'ALPS', 'ALTS', 'AWLS', 'ELLS', 'ILLS']
# ALLY ['ABLY', 'AGLY', 'ALAY', 'ALKY', 'ALLS', 'ILLY']
# ALMA ['AGMA', 'ALBA', 'ALFA', 'ALGA', 'ALME', 'ALMS', 'ATMA']
# ALME ['ACME', 'ALAE', 'ALBE', 'ALEE', 'ALMA', 'ALMS', 'ALOE']
# ALMS ['AIMS', 'ALAS', 'ALBS', 'ALES', 'ALFS', 'ALLS', 'ALMA', 'ALME', 'ALPS', 'ALTS', 'ARMS', 'ELMS', 'OLMS']
# ALOD ['ALOE', 'ALOW', 'APOD', 'CLOD', 'PLOD']
# ALOE ['ALAE', 'ALBE', 'ALEE', 'ALME', 'ALOD', 'ALOW', 'FLOE', 'SLOE']
# ALOW ['ALEW', 'ALOD', 'ALOE', 'ANOW', 'AROW', 'AVOW', 'BLOW', 'CLOW', 'FLOW', 'GLOW', 'PLOW', 'SLOW']
# ALPS ['ALAS', 'ALBS', 'ALES', 'ALFS', 'ALLS', 'ALMS', 'ALTS', 'AMPS', 'APPS', 'ASPS']
# ALSO ['ALCO', 'ALKO', 'ALTO', 'APSO']
# ALTO ['ALCO', 'ALKO', 'ALSO', 'ALTS', 'AUTO']
# ALTS ['ACTS', 'AITS', 'ALAS', 'ALBS', 'ALES', 'ALFS', 'ALLS', 'ALMS', 'ALPS', 'ALTO', 'ANTS', 'APTS', 'ARTS', 'ELTS']
# ALUM ['ARUM', 'GLUM', 'PLUM', 'SLUM']
# AMAH ['AMAS', 'AYAH']
# AMAS ['ABAS', 'AGAS', 'AIAS', 'ALAS', 'AMAH', 'AMIS', 'AMPS', 'AMUS', 'ANAS', 'AVAS']
# AMBO ['AMMO', 'UMBO']
# AMEN ['AGEN', 'AMIN', 'OMEN']
# AMIA ['AMID', 'AMIE', 'AMIN', 'AMIR', 'AMIS', 'AMLA', 'ARIA']
# AMID ['ABID', 'ACID', 'AMIA', 'AMIE', 'AMIN', 'AMIR', 'AMIS', 'ARID', 'AVID', 'IMID']
# AMIE ['AMIA', 'AMID', 'AMIN', 'AMIR', 'AMIS']
# AMIN ['AGIN', 'AKIN', 'AMEN', 'AMIA', 'AMID', 'AMIE', 'AMIR', 'AMIS', 'AYIN']
# AMIR ['AMIA', 'AMID', 'AMIE', 'AMIN', 'AMIS', 'EMIR', 'SMIR']
# AMIS ['AHIS', 'AMAS', 'AMIA', 'AMID', 'AMIE', 'AMIN', 'AMIR', 'AMPS', 'AMUS', 'ANIS', 'ARIS', 'AXIS']
# AMLA ['AMIA', 'AULA']
# AMMO ['AMBO']
# AMOK ['ATOK']
# AMPS ['ALPS', 'AMAS', 'AMIS', 'AMUS', 'APPS', 'ASPS', 'IMPS', 'UMPS']
# AMUS ['AMAS', 'AMIS', 'AMPS', 'ANUS', 'AYUS', 'EMUS']
# AMYL ['ACYL', 'ARYL']
# ANAL ['ANAN', 'ANAS', 'ANIL', 'AVAL', 'AXAL']
# ANAN ['ALAN', 'ANAL', 'ANAS', 'ANON', 'AZAN']
# ANAS ['ABAS', 'AGAS', 'AIAS', 'ALAS', 'AMAS', 'ANAL', 'ANAN', 'ANDS', 'ANES', 'ANIS', 'ANNS', 'ANTS', 'ANUS', 'AVAS', 'MNAS']
# ANCE ['ANTE', 'ONCE', 'UNCE']
# ANDS ['ADDS', 'AIDS', 'ANAS', 'ANES', 'ANIS', 'ANNS', 'ANTS', 'ANUS', 'ARDS', 'ENDS']
# ANES ['ACES', 'AGES', 'AKES', 'ALES', 'ANAS', 'ANDS', 'ANEW', 'ANIS', 'ANNS', 'ANTS', 'ANUS', 'APES', 'ARES', 'ATES', 'AVES', 'AWES', 'AXES', 'AYES', 'ENES', 'ONES']
# ANEW ['ALEW', 'ANES', 'ANOW', 'AREW', 'ENEW', 'KNEW']
# ANGA ['AIGA', 'ALGA', 'ANNA', 'ANOA', 'ANSA', 'ANTA']
# ANIL ['ANAL', 'ANIS', 'ARIL', 'AXIL']
# ANIS ['AHIS', 'AMIS', 'ANAS', 'ANDS', 'ANES', 'ANIL', 'ANNS', 'ANTS', 'ANUS', 'ARIS', 'AXIS', 'UNIS']
# ANKH []
# ANNA ['ANGA', 'ANNO', 'ANNS', 'ANOA', 'ANSA', 'ANTA', 'ARNA']
# ANNO ['ANNA', 'ANNS']
# ANNS ['AINS', 'ANAS', 'ANDS', 'ANES', 'ANIS', 'ANNA', 'ANNO', 'ANTS', 'ANUS', 'AWNS', 'INNS']
# ANOA ['ANGA', 'ANNA', 'ANON', 'ANOW', 'ANSA', 'ANTA']
# ANON ['AEON', 'AGON', 'ANAN', 'ANOA', 'ANOW', 'AXON', 'AZON']
# ANOW ['ALOW', 'ANEW', 'ANOA', 'ANON', 'AROW', 'AVOW', 'ENOW', 'GNOW', 'KNOW', 'SNOW']
# ANSA ['ANGA', 'ANNA', 'ANOA', 'ANTA']
# ANTA ['ACTA', 'ANGA', 'ANNA', 'ANOA', 'ANSA', 'ANTE', 'ANTI', 'ANTS']
# ANTE ['ANCE', 'ANTA', 'ANTI', 'ANTS']
# ANTI ['ANTA', 'ANTE', 'ANTS', 'ARTI', 'INTI']
# ANTS ['ACTS', 'AITS', 'ALTS', 'ANAS', 'ANDS', 'ANES', 'ANIS', 'ANNS', 'ANTA', 'ANTE', 'ANTI', 'ANUS', 'APTS', 'ARTS']
# ANUS ['AMUS', 'ANAS', 'ANDS', 'ANES', 'ANIS', 'ANNS', 'ANTS', 'AYUS', 'GNUS', 'ONUS']
# APAY ['ALAY', 'AWAY', 'SPAY']
# APED ['ABED', 'ACED', 'AGED', 'AHED', 'AKED', 'APER', 'APES', 'APEX', 'APOD', 'ARED', 'AWED', 'AXED', 'OPED', 'SPED']
# APER ['ACER', 'AGER', 'APED', 'APES', 'APEX', 'AVER']
# APES ['ACES', 'AGES', 'AKES', 'ALES', 'ANES', 'APED', 'APER', 'APEX', 'APOS', 'APPS', 'APTS', 'ARES', 'ATES', 'AVES', 'AWES', 'AXES', 'AYES', 'OPES']
# APEX ['APED', 'APER', 'APES']
# APOD ['ALOD', 'APED', 'APOS', 'SPOD']
# APOS ['ABOS', 'ADOS', 'APES', 'APOD', 'APPS', 'APTS', 'AVOS', 'EPOS']
# APPS ['ALPS', 'AMPS', 'APES', 'APOS', 'APTS', 'ASPS']
# APSE ['APSO', 'ARSE']
# APSO ['ALSO', 'APSE']
# APTS ['ACTS', 'AITS', 'ALTS', 'ANTS', 'APES', 'APOS', 'APPS', 'ARTS', 'OPTS']
# AQUA ['ATUA']
# ARAK ['ARAR', 'BRAK']
# ARAR ['AFAR', 'AGAR', 'AJAR', 'ALAR', 'ARAK', 'ASAR']
# ARBA ['ABBA', 'ALBA', 'ARBS', 'AREA', 'ARIA', 'ARNA', 'ARPA']
# ARBS ['ABBS', 'ALBS', 'ARBA', 'ARCS', 'ARDS', 'ARES', 'ARFS', 'ARIS', 'ARKS', 'ARMS', 'ARTS', 'ORBS', 'URBS']
# ARCH ['ARCO', 'ARCS']
# ARCO ['ALCO', 'ARCH', 'ARCS', 'ARVO']
# ARCS ['ARBS', 'ARCH', 'ARCO', 'ARDS', 'ARES', 'ARFS', 'ARIS', 'ARKS', 'ARMS', 'ARTS', 'ORCS']
# ARDS ['ADDS', 'AIDS', 'ANDS', 'ARBS', 'ARCS', 'ARES', 'ARFS', 'ARIS', 'ARKS', 'ARMS', 'ARTS', 'ORDS', 'URDS']
# AREA ['ARBA', 'ARED', 'AREG', 'ARES', 'ARET', 'AREW', 'ARIA', 'ARNA', 'ARPA', 'ASEA', 'UREA']
# ARED ['ABED', 'ACED', 'AGED', 'AHED', 'AKED', 'APED', 'AREA', 'AREG', 'ARES', 'ARET', 'AREW', 'ARID', 'AWED', 'AXED', 'BRED', 'CRED', 'ERED', 'IRED']
# AREG ['AREA', 'ARED', 'ARES', 'ARET', 'AREW', 'DREG']
# ARES ['ACES', 'AGES', 'AKES', 'ALES', 'ANES', 'APES', 'ARBS', 'ARCS', 'ARDS', 'AREA', 'ARED', 'AREG', 'ARET', 'AREW', 'ARFS', 'ARIS', 'ARKS', 'ARMS', 'ARTS', 'ATES', 'AVES', 'AWES', 'AXES', 'AYES', 'ERES', 'IRES', 'ORES', 'TRES', 'URES']
# ARET ['ABET', 'AREA', 'ARED', 'AREG', 'ARES', 'AREW', 'FRET', 'TRET']
# AREW ['ALEW', 'ANEW', 'AREA', 'ARED', 'AREG', 'ARES', 'ARET', 'AROW', 'BREW', 'CREW', 'DREW', 'GREW', 'TREW']
# ARFS ['ALFS', 'ARBS', 'ARCS', 'ARDS', 'ARES', 'ARIS', 'ARKS', 'ARMS', 'ARTS', 'AUFS', 'ORFS']
# ARIA ['AMIA', 'ARBA', 'AREA', 'ARID', 'ARIL', 'ARIS', 'ARNA', 'ARPA']
# ARID ['ABID', 'ACID', 'AMID', 'ARED', 'ARIA', 'ARIL', 'ARIS', 'AVID', 'GRID', 'IRID']
# ARIL ['ANIL', 'ARIA', 'ARID', 'ARIS', 'ARYL', 'AXIL', 'VRIL']
# ARIS ['AHIS', 'AMIS', 'ANIS', 'ARBS', 'ARCS', 'ARDS', 'ARES', 'ARFS', 'ARIA', 'ARID', 'ARIL', 'ARKS', 'ARMS', 'ARTS', 'AXIS', 'BRIS', 'CRIS', 'FRIS', 'GRIS', 'IRIS', 'KRIS', 'SRIS']
# ARKS ['ARBS', 'ARCS', 'ARDS', 'ARES', 'ARFS', 'ARIS', 'ARMS', 'ARTS', 'ASKS', 'AUKS', 'ERKS', 'IRKS']
# ARLE ['ABLE', 'ARSE', 'AXLE', 'ORLE']
# ARMS ['AIMS', 'ALMS', 'ARBS', 'ARCS', 'ARDS', 'ARES', 'ARFS', 'ARIS', 'ARKS', 'ARMY', 'ARTS']
# ARMY ['ARMS', 'ARSY', 'ARTY']
# ARNA ['ANNA', 'ARBA', 'AREA', 'ARIA', 'ARPA']
# AROW ['ALOW', 'ANOW', 'AREW', 'AVOW', 'BROW', 'CROW', 'DROW', 'FROW', 'GROW', 'PROW', 'TROW', 'VROW']
# ARPA ['ARBA', 'AREA', 'ARIA', 'ARNA']
# ARSE ['APSE', 'ARLE', 'ARSY']
# ARSY ['ARMY', 'ARSE', 'ARTY']
# ARTI ['ANTI', 'ARTS', 'ARTY']
# ARTS ['ACTS', 'AITS', 'ALTS', 'ANTS', 'APTS', 'ARBS', 'ARCS', 'ARDS', 'ARES', 'ARFS', 'ARIS', 'ARKS', 'ARMS', 'ARTI', 'ARTY', 'ORTS']
# ARTY ['ARMY', 'ARSY', 'ARTI', 'ARTS']
# ARUM ['ALUM', 'DRUM', 'GRUM']
# ARVO ['ARCO']
# ARYL ['ACYL', 'AMYL', 'ARIL']
# ASAR ['AFAR', 'AGAR', 'AJAR', 'ALAR', 'ARAR', 'KSAR', 'OSAR', 'TSAR']
# ASCI []
# ASEA ['AREA']
# ASHY ['ACHY']
# ASKS ['ARKS', 'ASPS', 'AUKS', 'TSKS']
# ASPS ['ALPS', 'AMPS', 'APPS', 'ASKS']
# ATAP ['ALAP', 'ATOP', 'STAP']
# ATES ['ACES', 'AGES', 'AKES', 'ALES', 'ANES', 'APES', 'ARES', 'AVES', 'AWES', 'AXES', 'AYES', 'UTES']
# ATMA ['AGMA', 'ALMA', 'ATUA']
# ATOC ['ATOK', 'ATOM', 'ATOP']
# ATOK ['AMOK', 'ATOC', 'ATOM', 'ATOP']
# ATOM ['ATOC', 'ATOK', 'ATOP']
# ATOP ['ATAP', 'ATOC', 'ATOK', 'ATOM', 'STOP']
# ATUA ['AQUA', 'ATMA']
# AUFS ['ALFS', 'ARFS', 'AUKS']
# AUKS ['ARKS', 'ASKS', 'AUFS', 'EUKS', 'OUKS', 'SUKS', 'YUKS']
# AULA ['AMLA', 'AULD', 'AURA', 'GULA', 'HULA', 'KULA', 'PULA']
# AULD ['AULA', 'OULD']
# AUNE ['ACNE', 'AINE', 'AUNT', 'DUNE', 'KUNE', 'LUNE', 'RUNE', 'TUNE']
# AUNT ['AUNE', 'BUNT', 'CUNT', 'DUNT', 'HUNT', 'LUNT', 'MUNT', 'PUNT', 'RUNT']
# AURA ['AULA', 'BURA', 'DURA', 'JURA', 'MURA', 'SURA']
# AUTO ['ALTO']
# AVAL ['ANAL', 'AVAS', 'AVEL', 'AXAL', 'OVAL']
# AVAS ['ABAS', 'AGAS', 'AIAS', 'ALAS', 'AMAS', 'ANAS', 'AVAL', 'AVES', 'AVOS', 'KVAS', 'UVAS']
# AVEL ['AVAL', 'AVER', 'AVES', 'AXEL', 'OVEL']
# AVER ['ACER', 'AGER', 'APER', 'AVEL', 'AVES', 'EVER', 'OVER']
# AVES ['ACES', 'AGES', 'AKES', 'ALES', 'ANES', 'APES', 'ARES', 'ATES', 'AVAS', 'AVEL', 'AVER', 'AVOS', 'AWES', 'AXES', 'AYES', 'EVES']
# AVID ['ABID', 'ACID', 'AMID', 'ARID']
# AVOS ['ABOS', 'ADOS', 'APOS', 'AVAS', 'AVES', 'AVOW', 'EVOS']
# AVOW ['ALOW', 'ANOW', 'AROW', 'AVOS']
# AWAY ['ALAY', 'APAY', 'AWNY', 'AWRY', 'SWAY', 'TWAY']
# AWDL ['AWOL']
# AWED ['ABED', 'ACED', 'AGED', 'AHED', 'AKED', 'APED', 'ARED', 'AWEE', 'AWES', 'AXED', 'OWED']
# AWEE ['AGEE', 'AJEE', 'AKEE', 'ALEE', 'AWED', 'AWES', 'SWEE', 'TWEE']
# AWES ['ACES', 'AGES', 'AKES', 'ALES', 'ANES', 'APES', 'ARES', 'ATES', 'AVES', 'AWED', 'AWEE', 'AWLS', 'AWNS', 'AXES', 'AYES', 'EWES', 'OWES']
# AWLS ['AALS', 'AILS', 'ALLS', 'AWES', 'AWNS', 'OWLS']
# AWNS ['AINS', 'ANNS', 'AWES', 'AWLS', 'AWNY', 'OWNS']
# AWNY ['AWAY', 'AWNS', 'AWRY']
# AWOL ['AWDL']
# AWRY ['ADRY', 'AERY', 'AIRY', 'AWAY', 'AWNY']
# AXAL ['ANAL', 'AVAL', 'AXEL', 'AXIL']
# AXED ['ABED', 'ACED', 'AGED', 'AHED', 'AKED', 'APED', 'ARED', 'AWED', 'AXEL', 'AXES', 'EXED']
# AXEL ['AVEL', 'AXAL', 'AXED', 'AXES', 'AXIL']
# AXES ['ACES', 'AGES', 'AKES', 'ALES', 'ANES', 'APES', 'ARES', 'ATES', 'AVES', 'AWES', 'AXED', 'AXEL', 'AXIS', 'AYES', 'EXES', 'OXES']
# AXIL ['ANIL', 'ARIL', 'AXAL', 'AXEL', 'AXIS']
# AXIS ['AHIS', 'AMIS', 'ANIS', 'ARIS', 'AXES', 'AXIL']
# AXLE ['ABLE', 'ARLE']
# AXON ['AEON', 'AGON', 'ANON', 'AZON', 'EXON']
# AYAH ['AMAH']
# AYES ['ACES', 'AGES', 'AKES', 'ALES', 'ANES', 'APES', 'ARES', 'ATES', 'AVES', 'AWES', 'AXES', 'AYUS', 'BYES', 'DYES', 'EYES', 'HYES', 'KYES', 'LYES', 'NYES', 'OYES', 'PYES', 'RYES', 'SYES', 'TYES', 'WYES']
# AYIN ['AGIN', 'AKIN', 'AMIN', 'PYIN', 'TYIN']
# AYRE ['ACRE', 'BYRE', 'EYRE', 'GYRE', 'LYRE', 'PYRE', 'TYRE']
# AYUS ['AMUS', 'ANUS', 'AYES', 'KYUS']
# AZAN ['ALAN', 'ANAN', 'AZON']
# AZON ['AEON', 'AGON', 'ANON', 'AXON', 'AZAN']
# AZYM []
# BAAL ['BAAS', 'BAEL', 'BAIL', 'BALL', 'BAWL', 'KAAL', 'PAAL', 'TAAL']
# BAAS ['BAAL', 'BACS', 'BADS', 'BAGS', 'BALS', 'BAMS', 'BANS', 'BAPS', 'BARS', 'BASS', 'BATS', 'BAYS', 'BIAS', 'BOAS', 'BRAS', 'CAAS', 'FAAS', 'KAAS', 'MAAS']
# BABA ['BABE', 'BABU', 'BABY', 'BOBA', 'BUBA', 'CABA', 'YABA']
# BABE ['BABA', 'BABU', 'BABY', 'BADE', 'BAKE', 'BALE', 'BANE', 'BARE', 'BASE', 'BATE', 'BAYE', 'MABE', 'NABE', 'SABE']
# BABU ['BABA', 'BABE', 'BABY', 'BAJU', 'BALU', 'BAPU', 'BUBU', 'HABU', 'TABU']
# BABY ['BABA', 'BABE', 'BABU', 'GABY']
# BACH ['BACK', 'BACS', 'BAGH', 'BASH', 'BATH', 'EACH', 'MACH', 'NACH', 'RACH', 'TACH']
# BACK ['BACH', 'BACS', 'BALK', 'BANK', 'BARK', 'BASK', 'BAUK', 'BECK', 'BOCK', 'BUCK', 'DACK', 'HACK', 'JACK', 'LACK', 'MACK', 'PACK', 'RACK', 'SACK', 'TACK', 'WACK', 'YACK', 'ZACK']
# BACS ['BAAS', 'BACH', 'BACK', 'BADS', 'BAGS', 'BALS', 'BAMS', 'BANS', 'BAPS', 'BARS', 'BASS', 'BATS', 'BAYS', 'LACS', 'MACS', 'PACS', 'SACS', 'VACS']
# BADE ['BABE', 'BADS', 'BAKE', 'BALE', 'BANE', 'BARE', 'BASE', 'BATE', 'BAYE', 'BEDE', 'BIDE', 'BODE', 'BYDE', 'CADE', 'FADE', 'GADE', 'HADE', 'JADE', 'KADE', 'LADE', 'MADE', 'RADE', 'SADE', 'VADE', 'WADE']
# BADS ['BAAS', 'BACS', 'BADE', 'BAGS', 'BALS', 'BAMS', 'BANS', 'BAPS', 'BARS', 'BASS', 'BATS', 'BAYS', 'BEDS', 'BIDS', 'BODS', 'BUDS', 'CADS', 'DADS', 'FADS', 'GADS', 'HADS', 'LADS', 'MADS', 'NADS', 'PADS', 'RADS', 'SADS', 'TADS', 'WADS', 'YADS']
# BAEL ['BAAL', 'BAIL', 'BALL', 'BAWL', 'BHEL', 'TAEL']
# BAFF ['BAFT', 'BARF', 'BIFF', 'BOFF', 'BUFF', 'CAFF', 'DAFF', 'FAFF', 'GAFF', 'HAFF', 'NAFF', 'RAFF', 'WAFF', 'YAFF']
# BAFT ['BAFF', 'BAHT', 'BAIT', 'BANT', 'BAST', 'BATT', 'BAYT', 'DAFT', 'HAFT', 'RAFT', 'SAFT', 'WAFT']
# BAGH ['BACH', 'BAGS', 'BASH', 'BATH']
# BAGS ['BAAS', 'BACS', 'BADS', 'BAGH', 'BALS', 'BAMS', 'BANS', 'BAPS', 'BARS', 'BASS', 'BATS', 'BAYS', 'BEGS', 'BIGS', 'BOGS', 'BUGS', 'CAGS', 'DAGS', 'FAGS', 'GAGS', 'HAGS', 'JAGS', 'LAGS', 'MAGS', 'NAGS', 'RAGS', 'SAGS', 'TAGS', 'VAGS', 'WAGS', 'YAGS', 'ZAGS']
# BAHT ['BAFT', 'BAIT', 'BANT', 'BAST', 'BATT', 'BAYT']
# BAIL ['BAAL', 'BAEL', 'BAIT', 'BALL', 'BAWL', 'BOIL', 'FAIL', 'HAIL', 'JAIL', 'KAIL', 'MAIL', 'NAIL', 'PAIL', 'RAIL', 'SAIL', 'TAIL', 'VAIL', 'WAIL']
# BAIT ['BAFT', 'BAHT', 'BAIL', 'BANT', 'BAST', 'BATT', 'BAYT', 'BRIT', 'GAIT', 'RAIT', 'TAIT', 'WAIT']
# BAJU ['BABU', 'BALU', 'BAPU']
# BAKE ['BABE', 'BADE', 'BALE', 'BANE', 'BARE', 'BASE', 'BATE', 'BAYE', 'BIKE', 'BOKE', 'BUKE', 'BYKE', 'CAKE', 'FAKE', 'HAKE', 'JAKE', 'LAKE', 'MAKE', 'RAKE', 'SAKE', 'TAKE', 'WAKE']
# BALD ['BALE', 'BALK', 'BALL', 'BALM', 'BALS', 'BALU', 'BAND', 'BARD', 'BAUD', 'BAWD', 'BOLD', 'WALD', 'YALD']
# BALE ['BABE', 'BADE', 'BAKE', 'BALD', 'BALK', 'BALL', 'BALM', 'BALS', 'BALU', 'BANE', 'BARE', 'BASE', 'BATE', 'BAYE', 'BILE', 'BOLE', 'DALE', 'EALE', 'GALE', 'HALE', 'KALE', 'MALE', 'PALE', 'RALE', 'SALE', 'TALE', 'VALE', 'WALE', 'YALE']
# BALK ['BACK', 'BALD', 'BALE', 'BALL', 'BALM', 'BALS', 'BALU', 'BANK', 'BARK', 'BASK', 'BAUK', 'BILK', 'BULK', 'CALK', 'TALK', 'WALK']
# BALL ['BAAL', 'BAEL', 'BAIL', 'BALD', 'BALE', 'BALK', 'BALM', 'BALS', 'BALU', 'BAWL', 'BELL', 'BILL', 'BOLL', 'BULL', 'CALL', 'FALL', 'GALL', 'HALL', 'LALL', 'MALL', 'PALL', 'SALL', 'TALL', 'WALL']
# BALM ['BALD', 'BALE', 'BALK', 'BALL', 'BALS', 'BALU', 'BARM', 'CALM', 'HALM', 'MALM', 'PALM']
# BALS ['AALS', 'BAAS', 'BACS', 'BADS', 'BAGS', 'BALD', 'BALE', 'BALK', 'BALL', 'BALM', 'BALU', 'BAMS', 'BANS', 'BAPS', 'BARS', 'BASS', 'BATS', 'BAYS', 'BELS', 'DALS', 'GALS', 'MALS', 'PALS', 'SALS']
# BALU ['BABU', 'BAJU', 'BALD', 'BALE', 'BALK', 'BALL', 'BALM', 'BALS', 'BAPU']
# BAMS ['BAAS', 'BACS', 'BADS', 'BAGS', 'BALS', 'BANS', 'BAPS', 'BARS', 'BASS', 'BATS', 'BAYS', 'BUMS', 'CAMS', 'DAMS', 'GAMS', 'HAMS', 'JAMS', 'LAMS', 'MAMS', 'NAMS', 'PAMS', 'RAMS', 'SAMS', 'TAMS', 'YAMS']
# BANC ['BAND', 'BANE', 'BANG', 'BANI', 'BANK', 'BANS', 'BANT']
# BAND ['BALD', 'BANC', 'BANE', 'BANG', 'BANI', 'BANK', 'BANS', 'BANT', 'BARD', 'BAUD', 'BAWD', 'BEND', 'BIND', 'BOND', 'BUND', 'FAND', 'HAND', 'LAND', 'MAND', 'PAND', 'RAND', 'SAND', 'WAND']
# BANE ['BABE', 'BADE', 'BAKE', 'BALE', 'BANC', 'BAND', 'BANG', 'BANI', 'BANK', 'BANS', 'BANT', 'BARE', 'BASE', 'BATE', 'BAYE', 'BENE', 'BINE', 'BONE', 'CANE', 'FANE', 'GANE', 'JANE', 'KANE', 'LANE', 'MANE', 'NANE', 'PANE', 'SANE', 'TANE', 'VANE', 'WANE']
# BANG ['BANC', 'BAND', 'BANE', 'BANI', 'BANK', 'BANS', 'BANT', 'BING', 'BONG', 'BUNG', 'CANG', 'DANG', 'FANG', 'GANG', 'HANG', 'KANG', 'LANG', 'MANG', 'PANG', 'RANG', 'SANG', 'TANG', 'VANG', 'WANG', 'YANG']
# BANI ['BANC', 'BAND', 'BANE', 'BANG', 'BANK', 'BANS', 'BANT', 'BENI', 'MANI', 'RANI']
# BANK ['BACK', 'BALK', 'BANC', 'BAND', 'BANE', 'BANG', 'BANI', 'BANS', 'BANT', 'BARK', 'BASK', 'BAUK', 'BINK', 'BONK', 'BUNK', 'DANK', 'FANK', 'HANK', 'LANK', 'RANK', 'SANK', 'TANK', 'WANK', 'YANK']
# BANS ['BAAS', 'BACS', 'BADS', 'BAGS', 'BALS', 'BAMS', 'BANC', 'BAND', 'BANE', 'BANG', 'BANI', 'BANK', 'BANT', 'BAPS', 'BARS', 'BASS', 'BATS', 'BAYS', 'BENS', 'BINS', 'BUNS', 'CANS', 'DANS', 'EANS', 'FANS', 'GANS', 'KANS', 'MANS', 'NANS', 'PANS', 'SANS', 'TANS', 'VANS', 'WANS']
# BANT ['BAFT', 'BAHT', 'BAIT', 'BANC', 'BAND', 'BANE', 'BANG', 'BANI', 'BANK', 'BANS', 'BAST', 'BATT', 'BAYT', 'BENT', 'BINT', 'BUNT', 'CANT', 'DANT', 'GANT', 'HANT', 'KANT', 'LANT', 'PANT', 'RANT', 'SANT', 'VANT', 'WANT']
# BAPS ['BAAS', 'BACS', 'BADS', 'BAGS', 'BALS', 'BAMS', 'BANS', 'BAPU', 'BARS', 'BASS', 'BATS', 'BAYS', 'BOPS', 'CAPS', 'DAPS', 'GAPS', 'HAPS', 'JAPS', 'LAPS', 'MAPS', 'NAPS', 'PAPS', 'RAPS', 'SAPS', 'TAPS', 'WAPS', 'YAPS', 'ZAPS']
# BAPU ['BABU', 'BAJU', 'BALU', 'BAPS', 'HAPU', 'TAPU']
# BARB ['BARD', 'BARE', 'BARF', 'BARK', 'BARM', 'BARN', 'BARP', 'BARS', 'BURB', 'CARB', 'DARB', 'GARB', 'WARB']
# BARD ['BALD', 'BAND', 'BARB', 'BARE', 'BARF', 'BARK', 'BARM', 'BARN', 'BARP', 'BARS', 'BAUD', 'BAWD', 'BIRD', 'BORD', 'BURD', 'CARD', 'EARD', 'FARD', 'HARD', 'LARD', 'MARD', 'NARD', 'PARD', 'SARD', 'WARD', 'YARD']
# BARE ['BABE', 'BADE', 'BAKE', 'BALE', 'BANE', 'BARB', 'BARD', 'BARF', 'BARK', 'BARM', 'BARN', 'BARP', 'BARS', 'BASE', 'BATE', 'BAYE', 'BERE', 'BORE', 'BYRE', 'CARE', 'DARE', 'FARE', 'GARE', 'HARE', 'LARE', 'MARE', 'NARE', 'PARE', 'RARE', 'TARE', 'VARE', 'WARE', 'YARE']
# BARF ['BAFF', 'BARB', 'BARD', 'BARE', 'BARK', 'BARM', 'BARN', 'BARP', 'BARS', 'ZARF']
# BARK ['BACK', 'BALK', 'BANK', 'BARB', 'BARD', 'BARE', 'BARF', 'BARM', 'BARN', 'BARP', 'BARS', 'BASK', 'BAUK', 'BERK', 'BIRK', 'BORK', 'BURK', 'CARK', 'DARK', 'HARK', 'JARK', 'KARK', 'LARK', 'MARK', 'NARK', 'PARK', 'RARK', 'SARK', 'WARK', 'YARK']
# BARM ['BALM', 'BARB', 'BARD', 'BARE', 'BARF', 'BARK', 'BARN', 'BARP', 'BARS', 'BERM', 'BORM', 'FARM', 'HARM', 'MARM', 'WARM']
# BARN ['BARB', 'BARD', 'BARE', 'BARF', 'BARK', 'BARM', 'BARP', 'BARS', 'BAWN', 'BORN', 'BURN', 'CARN', 'DARN', 'EARN', 'HARN', 'KARN', 'LARN', 'TARN', 'WARN', 'YARN']
# BARP ['BARB', 'BARD', 'BARE', 'BARF', 'BARK', 'BARM', 'BARN', 'BARS', 'BURP', 'CARP', 'HARP', 'JARP', 'PARP', 'TARP', 'WARP']
# BARS ['BAAS', 'BACS', 'BADS', 'BAGS', 'BALS', 'BAMS', 'BANS', 'BAPS', 'BARB', 'BARD', 'BARE', 'BARF', 'BARK', 'BARM', 'BARN', 'BARP', 'BASS', 'BATS', 'BAYS', 'BORS', 'BURS', 'CARS', 'EARS', 'FARS', 'GARS', 'JARS', 'LARS', 'MARS', 'OARS', 'PARS', 'SARS', 'TARS', 'VARS', 'WARS']
# BASE ['BABE', 'BADE', 'BAKE', 'BALE', 'BANE', 'BARE', 'BASH', 'BASK', 'BASS', 'BAST', 'BATE', 'BAYE', 'BISE', 'CASE', 'EASE', 'LASE', 'MASE', 'PASE', 'RASE', 'VASE', 'WASE']
# BASH ['BACH', 'BAGH', 'BASE', 'BASK', 'BASS', 'BAST', 'BATH', 'BISH', 'BOSH', 'BUSH', 'CASH', 'DASH', 'FASH', 'GASH', 'HASH', 'LASH', 'MASH', 'PASH', 'RASH', 'SASH', 'TASH', 'WASH']
# BASK ['BACK', 'BALK', 'BANK', 'BARK', 'BASE', 'BASH', 'BASS', 'BAST', 'BAUK', 'BISK', 'BOSK', 'BUSK', 'CASK', 'HASK', 'MASK', 'TASK']
# BASS ['BAAS', 'BACS', 'BADS', 'BAGS', 'BALS', 'BAMS', 'BANS', 'BAPS', 'BARS', 'BASE', 'BASH', 'BASK', 'BAST', 'BATS', 'BAYS', 'BOSS', 'BUSS', 'JASS', 'LASS', 'MASS', 'PASS', 'SASS', 'TASS']
# BAST ['BAFT', 'BAHT', 'BAIT', 'BANT', 'BASE', 'BASH', 'BASK', 'BASS', 'BATT', 'BAYT', 'BEST', 'BIST', 'BUST', 'CAST', 'EAST', 'FAST', 'GAST', 'HAST', 'LAST', 'MAST', 'OAST', 'PAST', 'RAST', 'VAST', 'WAST']
# BATE ['BABE', 'BADE', 'BAKE', 'BALE', 'BANE', 'BARE', 'BASE', 'BATH', 'BATS', 'BATT', 'BAYE', 'BETE', 'BITE', 'BUTE', 'BYTE', 'CATE', 'DATE', 'FATE', 'GATE', 'HATE', 'LATE', 'MATE', 'PATE', 'RATE', 'SATE', 'TATE', 'WATE', 'YATE']
# BATH ['BACH', 'BAGH', 'BASH', 'BATE', 'BATS', 'BATT', 'BETH', 'BOTH', 'EATH', 'GATH', 'HATH', 'LATH', 'MATH', 'OATH', 'PATH', 'RATH', 'TATH']
# BATS ['BAAS', 'BACS', 'BADS', 'BAGS', 'BALS', 'BAMS', 'BANS', 'BAPS', 'BARS', 'BASS', 'BATE', 'BATH', 'BATT', 'BAYS', 'BETS', 'BITS', 'BOTS', 'BUTS', 'CATS', 'EATS', 'FATS', 'GATS', 'HATS', 'KATS', 'LATS', 'MATS', 'NATS', 'OATS', 'PATS', 'QATS', 'RATS', 'TATS', 'VATS', 'WATS']
# BATT ['BAFT', 'BAHT', 'BAIT', 'BANT', 'BAST', 'BATE', 'BATH', 'BATS', 'BAYT', 'BITT', 'BOTT', 'BUTT', 'MATT', 'TATT', 'WATT']
# BAUD ['BALD', 'BAND', 'BARD', 'BAUK', 'BAUR', 'BAWD', 'DAUD', 'GAUD', 'HAUD', 'LAUD', 'MAUD', 'YAUD']
# BAUK ['BACK', 'BALK', 'BANK', 'BARK', 'BASK', 'BAUD', 'BAUR', 'BOUK', 'CAUK', 'JAUK', 'WAUK']
# BAUR ['BAUD', 'BAUK', 'BAWR', 'BLUR', 'DAUR', 'FAUR', 'GAUR', 'WAUR']
# BAWD ['BALD', 'BAND', 'BARD', 'BAUD', 'BAWL', 'BAWN', 'BAWR', 'DAWD', 'GAWD']
# BAWL ['BAAL', 'BAEL', 'BAIL', 'BALL', 'BAWD', 'BAWN', 'BAWR', 'BOWL', 'PAWL', 'WAWL', 'YAWL']
# BAWN ['BARN', 'BAWD', 'BAWL', 'BAWR', 'DAWN', 'FAWN', 'LAWN', 'MAWN', 'PAWN', 'RAWN', 'SAWN', 'YAWN']
# BAWR ['BAUR', 'BAWD', 'BAWL', 'BAWN', 'BOWR', 'MAWR']
# BAYE ['BABE', 'BADE', 'BAKE', 'BALE', 'BANE', 'BARE', 'BASE', 'BATE', 'BAYS', 'BAYT']
# BAYS ['BAAS', 'BACS', 'BADS', 'BAGS', 'BALS', 'BAMS', 'BANS', 'BAPS', 'BARS', 'BASS', 'BATS', 'BAYE', 'BAYT', 'BEYS', 'BOYS', 'BUYS', 'CAYS', 'DAYS', 'FAYS', 'GAYS', 'HAYS', 'JAYS', 'KAYS', 'LAYS', 'MAYS', 'NAYS', 'PAYS', 'RAYS', 'SAYS', 'TAYS', 'WAYS', 'YAYS']
# BAYT ['BAFT', 'BAHT', 'BAIT', 'BANT', 'BAST', 'BATT', 'BAYE', 'BAYS']
# BEAD ['BEAK', 'BEAM', 'BEAN', 'BEAR', 'BEAT', 'BEAU', 'BEND', 'BLAD', 'BRAD', 'DEAD', 'HEAD', 'LEAD', 'MEAD', 'READ', 'TEAD', 'YEAD']
# BEAK ['BEAD', 'BEAM', 'BEAN', 'BEAR', 'BEAT', 'BEAU', 'BECK', 'BERK', 'BOAK', 'BRAK', 'LEAK', 'PEAK', 'REAK', 'TEAK', 'WEAK']
# BEAM ['BEAD', 'BEAK', 'BEAN', 'BEAR', 'BEAT', 'BEAU', 'BERM', 'BLAM', 'LEAM', 'REAM', 'SEAM', 'TEAM']
# BEAN ['BEAD', 'BEAK', 'BEAM', 'BEAR', 'BEAT', 'BEAU', 'BEEN', 'BEIN', 'BRAN', 'DEAN', 'GEAN', 'JEAN', 'LEAN', 'MEAN', 'PEAN', 'REAN', 'SEAN', 'WEAN', 'YEAN']
# BEAR ['BEAD', 'BEAK', 'BEAM', 'BEAN', 'BEAT', 'BEAU', 'BEER', 'BOAR', 'DEAR', 'FEAR', 'GEAR', 'HEAR', 'LEAR', 'NEAR', 'PEAR', 'REAR', 'SEAR', 'TEAR', 'WEAR', 'YEAR']
# BEAT ['BEAD', 'BEAK', 'BEAM', 'BEAN', 'BEAR', 'BEAU', 'BEET', 'BELT', 'BENT', 'BEST', 'BHAT', 'BLAT', 'BOAT', 'BRAT', 'BUAT', 'FEAT', 'GEAT', 'HEAT', 'JEAT', 'LEAT', 'MEAT', 'NEAT', 'PEAT', 'SEAT', 'TEAT']
# BEAU ['BEAD', 'BEAK', 'BEAM', 'BEAN', 'BEAR', 'BEAT', 'BEDU']
# BECK ['BACK', 'BEAK', 'BERK', 'BOCK', 'BUCK', 'DECK', 'FECK', 'GECK', 'HECK', 'KECK', 'MECK', 'NECK', 'PECK', 'RECK']
# BEDE ['BADE', 'BEDS', 'BEDU', 'BENE', 'BERE', 'BETE', 'BIDE', 'BODE', 'BYDE', 'CEDE', 'REDE', 'YEDE']
# BEDS ['BADS', 'BEDE', 'BEDU', 'BEES', 'BEGS', 'BELS', 'BENS', 'BETS', 'BEYS', 'BIDS', 'BODS', 'BUDS', 'FEDS', 'GEDS', 'KEDS', 'MEDS', 'NEDS', 'PEDS', 'REDS', 'TEDS', 'WEDS', 'ZEDS']
# BEDU ['BEAU', 'BEDE', 'BEDS']
# BEEF ['BEEN', 'BEEP', 'BEER', 'BEES', 'BEET', 'KEEF', 'REEF']
# BEEN ['BEAN', 'BEEF', 'BEEP', 'BEER', 'BEES', 'BEET', 'BEIN', 'BIEN', 'BREN', 'DEEN', 'FEEN', 'KEEN', 'PEEN', 'REEN', 'SEEN', 'TEEN', 'WEEN']
# BEEP ['BEEF', 'BEEN', 'BEER', 'BEES', 'BEET', 'BOEP', 'DEEP', 'GEEP', 'JEEP', 'KEEP', 'LEEP', 'NEEP', 'PEEP', 'SEEP', 'VEEP', 'WEEP']
# BEER ['BEAR', 'BEEF', 'BEEN', 'BEEP', 'BEES', 'BEET', 'BIER', 'BRER', 'DEER', 'FEER', 'JEER', 'LEER', 'MEER', 'PEER', 'SEER', 'TEER', 'VEER', 'WEER']
# BEES ['BEDS', 'BEEF', 'BEEN', 'BEEP', 'BEER', 'BEET', 'BEGS', 'BELS', 'BENS', 'BETS', 'BEYS', 'BYES', 'CEES', 'DEES', 'FEES', 'GEES', 'JEES', 'LEES', 'MEES', 'PEES', 'REES', 'SEES', 'TEES', 'VEES', 'WEES', 'ZEES']
# BEET ['BEAT', 'BEEF', 'BEEN', 'BEEP', 'BEER', 'BEES', 'BELT', 'BENT', 'BEST', 'BLET', 'BOET', 'DEET', 'FEET', 'KEET', 'LEET', 'MEET', 'WEET']
# BEGO ['BEGS', 'REGO', 'SEGO', 'VEGO']
# BEGS ['BAGS', 'BEDS', 'BEES', 'BEGO', 'BELS', 'BENS', 'BETS', 'BEYS', 'BIGS', 'BOGS', 'BUGS', 'DEGS', 'FEGS', 'KEGS', 'LEGS', 'MEGS', 'NEGS', 'PEGS', 'REGS', 'SEGS', 'TEGS']
# BEIN ['BEAN', 'BEEN', 'BLIN', 'BRIN', 'MEIN', 'PEIN', 'REIN', 'VEIN', 'ZEIN']
# BELL ['BALL', 'BELS', 'BELT', 'BILL', 'BOLL', 'BULL', 'CELL', 'DELL', 'FELL', 'HELL', 'JELL', 'KELL', 'MELL', 'PELL', 'SELL', 'TELL', 'VELL', 'WELL', 'YELL']
# BELS ['BALS', 'BEDS', 'BEES', 'BEGS', 'BELL', 'BELT', 'BENS', 'BETS', 'BEYS', 'CELS', 'DELS', 'EELS', 'GELS', 'MELS', 'SELS', 'TELS', 'ZELS']
# BELT ['BEAT', 'BEET', 'BELL', 'BELS', 'BENT', 'BEST', 'BOLT', 'CELT', 'DELT', 'FELT', 'GELT', 'KELT', 'MELT', 'PELT', 'TELT', 'WELT', 'YELT']
# BEMA ['BETA', 'BIMA', 'BOMA', 'NEMA']
# BEND ['BAND', 'BEAD', 'BENE', 'BENI', 'BENJ', 'BENS', 'BENT', 'BIND', 'BOND', 'BUND', 'FEND', 'HEND', 'LEND', 'MEND', 'PEND', 'REND', 'SEND', 'TEND', 'VEND', 'WEND']
# BENE ['BANE', 'BEDE', 'BEND', 'BENI', 'BENJ', 'BENS', 'BENT', 'BERE', 'BETE', 'BINE', 'BONE', 'DENE', 'GENE', 'MENE', 'NENE', 'PENE', 'SENE', 'TENE']
# BENI ['BANI', 'BEND', 'BENE', 'BENJ', 'BENS', 'BENT', 'DENI', 'FENI', 'PENI']
# BENJ ['BEND', 'BENE', 'BENI', 'BENS', 'BENT']
# BENS ['BANS', 'BEDS', 'BEES', 'BEGS', 'BELS', 'BEND', 'BENE', 'BENI', 'BENJ', 'BENT', 'BETS', 'BEYS', 'BINS', 'BUNS', 'CENS', 'DENS', 'FENS', 'GENS', 'HENS', 'KENS', 'LENS', 'PENS', 'RENS', 'SENS', 'TENS', 'WENS', 'YENS']
# BENT ['BANT', 'BEAT', 'BEET', 'BELT', 'BEND', 'BENE', 'BENI', 'BENJ', 'BENS', 'BEST', 'BINT', 'BUNT', 'CENT', 'DENT', 'FENT', 'GENT', 'HENT', 'KENT', 'LENT', 'MENT', 'PENT', 'RENT', 'SENT', 'TENT', 'VENT', 'WENT']
# BERE ['BARE', 'BEDE', 'BENE', 'BERG', 'BERK', 'BERM', 'BETE', 'BORE', 'BYRE', 'CERE', 'DERE', 'FERE', 'GERE', 'HERE', 'LERE', 'MERE', 'PERE', 'SERE', 'WERE']
# BERG ['BERE', 'BERK', 'BERM', 'BURG']
# BERK ['BARK', 'BEAK', 'BECK', 'BERE', 'BERG', 'BERM', 'BIRK', 'BORK', 'BURK', 'JERK', 'MERK', 'NERK', 'PERK', 'SERK', 'YERK', 'ZERK']
# BERM ['BARM', 'BEAM', 'BERE', 'BERG', 'BERK', 'BORM', 'DERM', 'FERM', 'GERM', 'HERM', 'PERM', 'TERM']
# BEST ['BAST', 'BEAT', 'BEET', 'BELT', 'BENT', 'BIST', 'BUST', 'FEST', 'GEST', 'HEST', 'JEST', 'KEST', 'LEST', 'NEST', 'PEST', 'REST', 'TEST', 'VEST', 'WEST', 'YEST', 'ZEST']
# BETA ['BEMA', 'BETE', 'BETH', 'BETS', 'BOTA', 'FETA', 'GETA', 'KETA', 'META', 'SETA', 'WETA', 'ZETA']
# BETE ['BATE', 'BEDE', 'BENE', 'BERE', 'BETA', 'BETH', 'BETS', 'BITE', 'BUTE', 'BYTE', 'CETE', 'FETE', 'HETE', 'JETE', 'KETE', 'METE', 'NETE', 'RETE', 'TETE']
# BETH ['BATH', 'BETA', 'BETE', 'BETS', 'BOTH', 'HETH', 'METH', 'TETH']
# BETS ['BATS', 'BEDS', 'BEES', 'BEGS', 'BELS', 'BENS', 'BETA', 'BETE', 'BETH', 'BEYS', 'BITS', 'BOTS', 'BUTS', 'FETS', 'GETS', 'HETS', 'JETS', 'KETS', 'LETS', 'METS', 'NETS', 'PETS', 'RETS', 'SETS', 'TETS', 'VETS', 'WETS']
# BEVY ['LEVY']
# BEYS ['BAYS', 'BEDS', 'BEES', 'BEGS', 'BELS', 'BENS', 'BETS', 'BOYS', 'BUYS', 'DEYS', 'FEYS', 'HEYS', 'KEYS', 'LEYS', 'SEYS', 'UEYS', 'WEYS']
# BHAT ['BEAT', 'BHUT', 'BLAT', 'BOAT', 'BRAT', 'BUAT', 'CHAT', 'GHAT', 'KHAT', 'PHAT', 'SHAT', 'THAT', 'WHAT']
# BHEL ['BAEL']
# BHUT ['BHAT', 'BOUT', 'BRUT', 'CHUT', 'PHUT', 'SHUT']
# BIAS ['AIAS', 'BAAS', 'BIBS', 'BIDS', 'BIGS', 'BINS', 'BIOS', 'BITS', 'BOAS', 'BRAS', 'LIAS', 'PIAS', 'RIAS', 'VIAS']
# BIBB ['BIBS', 'JIBB', 'SIBB']
# BIBS ['BIAS', 'BIBB', 'BIDS', 'BIGS', 'BINS', 'BIOS', 'BITS', 'BOBS', 'BUBS', 'DIBS', 'FIBS', 'GIBS', 'JIBS', 'LIBS', 'MIBS', 'NIBS', 'RIBS', 'SIBS', 'VIBS']
# BICE ['BIDE', 'BIKE', 'BILE', 'BINE', 'BISE', 'BITE', 'BIZE', 'DICE', 'FICE', 'LICE', 'MICE', 'NICE', 'PICE', 'RICE', 'SICE', 'TICE', 'VICE', 'WICE']
# BIDE ['AIDE', 'BADE', 'BEDE', 'BICE', 'BIDI', 'BIDS', 'BIKE', 'BILE', 'BINE', 'BISE', 'BITE', 'BIZE', 'BODE', 'BYDE', 'CIDE', 'EIDE', 'HIDE', 'NIDE', 'RIDE', 'SIDE', 'TIDE', 'VIDE', 'WIDE']
# BIDI ['BIDE', 'BIDS', 'BUDI', 'MIDI', 'NIDI']
# BIDS ['AIDS', 'BADS', 'BEDS', 'BIAS', 'BIBS', 'BIDE', 'BIDI', 'BIGS', 'BINS', 'BIOS', 'BITS', 'BODS', 'BUDS', 'CIDS', 'FIDS', 'GIDS', 'KIDS', 'LIDS', 'MIDS', 'NIDS', 'RIDS', 'TIDS', 'VIDS', 'YIDS']
# BIEN ['BEEN', 'BIER', 'BREN', 'GIEN', 'LIEN', 'MIEN', 'SIEN']
# BIER ['BEER', 'BIEN', 'BIRR', 'BRER', 'FIER', 'KIER', 'LIER', 'PIER', 'TIER', 'VIER']
# BIFF ['BAFF', 'BOFF', 'BUFF', 'DIFF', 'JIFF', 'KIFF', 'MIFF', 'NIFF', 'RIFF', 'TIFF', 'ZIFF']
# BIGA ['AIGA', 'BIGG', 'BIGS', 'BIMA', 'GIGA', 'VIGA']
# BIGG ['BIGA', 'BIGS', 'BING', 'BIOG', 'MIGG', 'RIGG']
# BIGS ['BAGS', 'BEGS', 'BIAS', 'BIBS', 'BIDS', 'BIGA', 'BIGG', 'BINS', 'BIOS', 'BITS', 'BOGS', 'BUGS', 'CIGS', 'DIGS', 'FIGS', 'GIGS', 'JIGS', 'LIGS', 'MIGS', 'PIGS', 'RIGS', 'TIGS', 'VIGS', 'WIGS', 'ZIGS']
# BIKE ['BAKE', 'BICE', 'BIDE', 'BILE', 'BINE', 'BISE', 'BITE', 'BIZE', 'BOKE', 'BUKE', 'BYKE', 'DIKE', 'FIKE', 'HIKE', 'KIKE', 'LIKE', 'MIKE', 'PIKE', 'SIKE', 'TIKE', 'YIKE']
# BILE ['BALE', 'BICE', 'BIDE', 'BIKE', 'BILK', 'BILL', 'BINE', 'BISE', 'BITE', 'BIZE', 'BOLE', 'FILE', 'MILE', 'PILE', 'RILE', 'SILE', 'TILE', 'VILE', 'WILE']
# BILK ['BALK', 'BILE', 'BILL', 'BINK', 'BIRK', 'BISK', 'BULK', 'MILK', 'SILK']
# BILL ['BALL', 'BELL', 'BILE', 'BILK', 'BIRL', 'BOLL', 'BULL', 'CILL', 'DILL', 'FILL', 'GILL', 'HILL', 'JILL', 'KILL', 'LILL', 'MILL', 'NILL', 'PILL', 'RILL', 'SILL', 'TILL', 'VILL', 'WILL', 'YILL', 'ZILL']
# BIMA ['BEMA', 'BIGA', 'BOMA', 'LIMA', 'PIMA', 'RIMA', 'SIMA']
# BIND ['BAND', 'BEND', 'BINE', 'BING', 'BINK', 'BINS', 'BINT', 'BIRD', 'BOND', 'BUND', 'FIND', 'HIND', 'KIND', 'LIND', 'MIND', 'RIND', 'SIND', 'TIND', 'WIND']
# BINE ['AINE', 'BANE', 'BENE', 'BICE', 'BIDE', 'BIKE', 'BILE', 'BIND', 'BING', 'BINK', 'BINS', 'BINT', 'BISE', 'BITE', 'BIZE', 'BONE', 'CINE', 'DINE', 'EINE', 'FINE', 'KINE', 'LINE', 'MINE', 'NINE', 'PINE', 'RINE', 'SINE', 'TINE', 'VINE', 'WINE', 'ZINE']
# BING ['BANG', 'BIGG', 'BIND', 'BINE', 'BINK', 'BINS', 'BINT', 'BIOG', 'BONG', 'BUNG', 'DING', 'GING', 'HING', 'KING', 'LING', 'MING', 'PING', 'RING', 'SING', 'TING', 'WING', 'ZING']
# BINK ['BANK', 'BILK', 'BIND', 'BINE', 'BING', 'BINS', 'BINT', 'BIRK', 'BISK', 'BONK', 'BUNK', 'DINK', 'FINK', 'GINK', 'JINK', 'KINK', 'LINK', 'MINK', 'OINK', 'PINK', 'RINK', 'SINK', 'TINK', 'WINK']
# BINS ['AINS', 'BANS', 'BENS', 'BIAS', 'BIBS', 'BIDS', 'BIGS', 'BIND', 'BINE', 'BING', 'BINK', 'BINT', 'BIOS', 'BITS', 'BUNS', 'DINS', 'FINS', 'GINS', 'HINS', 'JINS', 'KINS', 'LINS', 'PINS', 'RINS', 'SINS', 'TINS', 'VINS', 'WINS', 'YINS', 'ZINS']
# BINT ['BANT', 'BENT', 'BIND', 'BINE', 'BING', 'BINK', 'BINS', 'BIST', 'BITT', 'BUNT', 'DINT', 'HINT', 'LINT', 'MINT', 'OINT', 'PINT', 'TINT', 'VINT']
# BIOG ['BIGG', 'BING', 'BIOS', 'BLOG', 'BROG']
# BIOS ['BIAS', 'BIBS', 'BIDS', 'BIGS', 'BINS', 'BIOG', 'BITS', 'BOOS', 'BROS', 'GIOS']
# BIRD ['BARD', 'BIND', 'BIRK', 'BIRL', 'BIRO', 'BIRR', 'BORD', 'BURD', 'GIRD', 'JIRD', 'YIRD']
# BIRK ['BARK', 'BERK', 'BILK', 'BINK', 'BIRD', 'BIRL', 'BIRO', 'BIRR', 'BISK', 'BORK', 'BURK', 'DIRK', 'FIRK', 'KIRK', 'LIRK', 'MIRK', 'YIRK']
# BIRL ['BILL', 'BIRD', 'BIRK', 'BIRO', 'BIRR', 'BURL', 'BYRL', 'CIRL', 'DIRL', 'GIRL', 'NIRL', 'PIRL', 'TIRL', 'VIRL']
# BIRO ['BIRD', 'BIRK', 'BIRL', 'BIRR', 'BITO', 'GIRO', 'MIRO', 'TIRO']
# BIRR ['BIER', 'BIRD', 'BIRK', 'BIRL', 'BIRO', 'BRRR', 'BURR', 'GIRR', 'TIRR', 'YIRR']
# BISE ['BASE', 'BICE', 'BIDE', 'BIKE', 'BILE', 'BINE', 'BISH', 'BISK', 'BIST', 'BITE', 'BIZE', 'MISE', 'PISE', 'RISE', 'VISE', 'WISE']
# BISH ['BASH', 'BISE', 'BISK', 'BIST', 'BOSH', 'BUSH', 'DISH', 'EISH', 'FISH', 'HISH', 'KISH', 'NISH', 'PISH', 'WISH']
# BISK ['BASK', 'BILK', 'BINK', 'BIRK', 'BISE', 'BISH', 'BIST', 'BOSK', 'BUSK', 'DISK', 'FISK', 'LISK', 'RISK']
# BIST ['BAST', 'BEST', 'BINT', 'BISE', 'BISH', 'BISK', 'BITT', 'BUST', 'CIST', 'FIST', 'GIST', 'HIST', 'KIST', 'LIST', 'MIST', 'SIST', 'WIST']
# BITE ['BATE', 'BETE', 'BICE', 'BIDE', 'BIKE', 'BILE', 'BINE', 'BISE', 'BITO', 'BITS', 'BITT', 'BIZE', 'BUTE', 'BYTE', 'CITE', 'DITE', 'GITE', 'KITE', 'LITE', 'MITE', 'NITE', 'RITE', 'SITE', 'TITE', 'VITE', 'WITE', 'YITE', 'ZITE']
# BITO ['BIRO', 'BITE', 'BITS', 'BITT', 'CITO']
# BITS ['AITS', 'BATS', 'BETS', 'BIAS', 'BIBS', 'BIDS', 'BIGS', 'BINS', 'BIOS', 'BITE', 'BITO', 'BITT', 'BOTS', 'BUTS', 'CITS', 'DITS', 'FITS', 'GITS', 'HITS', 'KITS', 'LITS', 'NITS', 'PITS', 'RITS', 'SITS', 'TITS', 'WITS', 'ZITS']
# BITT ['BATT', 'BINT', 'BIST', 'BITE', 'BITO', 'BITS', 'BOTT', 'BUTT', 'DITT', 'FITT', 'MITT', 'RITT']
# BIZE ['BICE', 'BIDE', 'BIKE', 'BILE', 'BINE', 'BISE', 'BITE', 'PIZE', 'SIZE']
# BLAB ['BLAD', 'BLAE', 'BLAG', 'BLAH', 'BLAM', 'BLAT', 'BLAW', 'BLAY', 'BLEB', 'BLOB', 'BLUB', 'BOAB', 'FLAB', 'SLAB']
# BLAD ['BEAD', 'BLAB', 'BLAE', 'BLAG', 'BLAH', 'BLAM', 'BLAT', 'BLAW', 'BLAY', 'BLED', 'BRAD', 'CLAD', 'GLAD']
# BLAE ['ALAE', 'BLAB', 'BLAD', 'BLAG', 'BLAH', 'BLAM', 'BLAT', 'BLAW', 'BLAY', 'BLEE', 'BLUE', 'BRAE', 'SLAE']
# BLAG ['BLAB', 'BLAD', 'BLAE', 'BLAH', 'BLAM', 'BLAT', 'BLAW', 'BLAY', 'BLOG', 'BRAG', 'CLAG', 'FLAG', 'SLAG']
# BLAH ['BLAB', 'BLAD', 'BLAE', 'BLAG', 'BLAM', 'BLAT', 'BLAW', 'BLAY']
# BLAM ['BEAM', 'BLAB', 'BLAD', 'BLAE', 'BLAG', 'BLAH', 'BLAT', 'BLAW', 'BLAY', 'CLAM', 'FLAM', 'GLAM', 'SLAM']
# BLAT ['BEAT', 'BHAT', 'BLAB', 'BLAD', 'BLAE', 'BLAG', 'BLAH', 'BLAM', 'BLAW', 'BLAY', 'BLET', 'BLOT', 'BOAT', 'BRAT', 'BUAT', 'CLAT', 'FLAT', 'PLAT', 'SLAT']
# BLAW ['BLAB', 'BLAD', 'BLAE', 'BLAG', 'BLAH', 'BLAM', 'BLAT', 'BLAY', 'BLEW', 'BLOW', 'BRAW', 'CLAW', 'FLAW', 'SLAW']
# BLAY ['ALAY', 'BLAB', 'BLAD', 'BLAE', 'BLAG', 'BLAH', 'BLAM', 'BLAT', 'BLAW', 'BLEY', 'BRAY', 'CLAY', 'FLAY', 'PLAY', 'SLAY']
# BLEB ['BLAB', 'BLED', 'BLEE', 'BLET', 'BLEW', 'BLEY', 'BLOB', 'BLUB', 'PLEB']
# BLED ['BLAD', 'BLEB', 'BLEE', 'BLET', 'BLEW', 'BLEY', 'BRED', 'FLED', 'GLED', 'PLED', 'SLED']
# BLEE ['ALEE', 'BLAE', 'BLEB', 'BLED', 'BLET', 'BLEW', 'BLEY', 'BLUE', 'BREE', 'FLEE', 'GLEE', 'SLEE']
# BLET ['BEET', 'BLAT', 'BLEB', 'BLED', 'BLEE', 'BLEW', 'BLEY', 'BLOT', 'BOET']
# BLEW ['ALEW', 'BLAW', 'BLEB', 'BLED', 'BLEE', 'BLET', 'BLEY', 'BLOW', 'BREW', 'CLEW', 'FLEW', 'PLEW', 'SLEW']
# BLEY ['BLAY', 'BLEB', 'BLED', 'BLEE', 'BLET', 'BLEW', 'BREY', 'FLEY', 'GLEY', 'SLEY']
# BLIN ['BEIN', 'BLIP', 'BRIN']
# BLIP ['BLIN', 'CLIP', 'FLIP', 'SLIP']
# BLOB ['BLAB', 'BLEB', 'BLOC', 'BLOG', 'BLOT', 'BLOW', 'BLUB', 'BOOB', 'GLOB', 'SLOB']
# BLOC ['BLOB', 'BLOG', 'BLOT', 'BLOW', 'FLOC']
# BLOG ['BIOG', 'BLAG', 'BLOB', 'BLOC', 'BLOT', 'BLOW', 'BROG', 'CLOG', 'FLOG', 'SLOG']
# BLOT ['BLAT', 'BLET', 'BLOB', 'BLOC', 'BLOG', 'BLOW', 'BOOT', 'CLOT', 'PLOT', 'SLOT']
# BLOW ['ALOW', 'BLAW', 'BLEW', 'BLOB', 'BLOC', 'BLOG', 'BLOT', 'BROW', 'CLOW', 'FLOW', 'GLOW', 'PLOW', 'SLOW']
# BLUB ['BLAB', 'BLEB', 'BLOB', 'BLUE', 'BLUR', 'CLUB', 'FLUB', 'SLUB']
# BLUE ['BLAE', 'BLEE', 'BLUB', 'BLUR', 'CLUE', 'FLUE', 'GLUE', 'PLUE', 'SLUE']
# BLUR ['BAUR', 'BLUB', 'BLUE', 'SLUR']
# BOAB ['BLAB', 'BOAK', 'BOAR', 'BOAS', 'BOAT', 'BOMB', 'BOOB', 'DOAB']
# BOAK ['BEAK', 'BOAB', 'BOAR', 'BOAS', 'BOAT', 'BOCK', 'BONK', 'BOOK', 'BORK', 'BOSK', 'BOUK', 'BRAK', 'SOAK']
# BOAR ['BEAR', 'BOAB', 'BOAK', 'BOAS', 'BOAT', 'BOOR', 'BOWR', 'HOAR', 'ROAR', 'SOAR', 'VOAR']
# BOAS ['BAAS', 'BIAS', 'BOAB', 'BOAK', 'BOAR', 'BOAT', 'BOBS', 'BODS', 'BOGS', 'BOHS', 'BOIS', 'BOKS', 'BOOS', 'BOPS', 'BORS', 'BOSS', 'BOTS', 'BOWS', 'BOYS', 'BRAS', 'GOAS', 'HOAS', 'KOAS', 'MOAS', 'POAS']
# BOAT ['BEAT', 'BHAT', 'BLAT', 'BOAB', 'BOAK', 'BOAR', 'BOAS', 'BOET', 'BOLT', 'BOOT', 'BORT', 'BOTT', 'BOUT', 'BRAT', 'BUAT', 'COAT', 'DOAT', 'GOAT', 'MOAT']
# BOBA ['BABA', 'BOBS', 'BOLA', 'BOMA', 'BONA', 'BORA', 'BOTA', 'BUBA', 'SOBA']
# BOBS ['BIBS', 'BOAS', 'BOBA', 'BODS', 'BOGS', 'BOHS', 'BOIS', 'BOKS', 'BOOS', 'BOPS', 'BORS', 'BOSS', 'BOTS', 'BOWS', 'BOYS', 'BUBS', 'COBS', 'DOBS', 'FOBS', 'GOBS', 'HOBS', 'JOBS', 'KOBS', 'LOBS', 'MOBS', 'NOBS', 'ROBS', 'SOBS', 'YOBS']
# BOCK ['BACK', 'BECK', 'BOAK', 'BONK', 'BOOK', 'BORK', 'BOSK', 'BOUK', 'BUCK', 'COCK', 'DOCK', 'HOCK', 'JOCK', 'LOCK', 'MOCK', 'NOCK', 'POCK', 'ROCK', 'SOCK', 'TOCK', 'WOCK', 'YOCK']
# BODE ['BADE', 'BEDE', 'BIDE', 'BODS', 'BODY', 'BOKE', 'BOLE', 'BONE', 'BORE', 'BYDE', 'CODE', 'LODE', 'MODE', 'NODE', 'RODE', 'YODE']
# BODS ['BADS', 'BEDS', 'BIDS', 'BOAS', 'BOBS', 'BODE', 'BODY', 'BOGS', 'BOHS', 'BOIS', 'BOKS', 'BOOS', 'BOPS', 'BORS', 'BOSS', 'BOTS', 'BOWS', 'BOYS', 'BUDS', 'CODS', 'DODS', 'GODS', 'HODS', 'LODS', 'MODS', 'NODS', 'PODS', 'RODS', 'SODS', 'TODS', 'YODS']
# BODY ['BODE', 'BODS', 'BOGY', 'BONY', 'BOXY', 'TODY']
# BOEP ['BEEP', 'BOET', 'POEP']
# BOET ['BEET', 'BLET', 'BOAT', 'BOEP', 'BOLT', 'BOOT', 'BORT', 'BOTT', 'BOUT', 'POET']
# BOFF ['BAFF', 'BIFF', 'BOYF', 'BUFF', 'COFF', 'DOFF', 'GOFF', 'KOFF', 'TOFF']
# BOGS ['BAGS', 'BEGS', 'BIGS', 'BOAS', 'BOBS', 'BODS', 'BOGY', 'BOHS', 'BOIS', 'BOKS', 'BOOS', 'BOPS', 'BORS', 'BOSS', 'BOTS', 'BOWS', 'BOYS', 'BUGS', 'COGS', 'DOGS', 'FOGS', 'HOGS', 'JOGS', 'LOGS', 'MOGS', 'NOGS', 'SOGS', 'TOGS', 'WOGS']
# BOGY ['BODY', 'BOGS', 'BONY', 'BOXY', 'DOGY', 'FOGY', 'LOGY', 'POGY']
# BOHO ['BOHS', 'BOKO', 'BOLO', 'BOYO', 'BOZO', 'COHO', 'SOHO', 'TOHO']
# BOHS ['BOAS', 'BOBS', 'BODS', 'BOGS', 'BOHO', 'BOIS', 'BOKS', 'BOOS', 'BOPS', 'BORS', 'BOSS', 'BOTS', 'BOWS', 'BOYS', 'DOHS', 'FOHS', 'HOHS', 'OOHS', 'SOHS']
# BOIL ['BAIL', 'BOIS', 'BOLL', 'BOOL', 'BOWL', 'COIL', 'FOIL', 'MOIL', 'NOIL', 'ROIL', 'SOIL', 'TOIL']
# BOIS ['BOAS', 'BOBS', 'BODS', 'BOGS', 'BOHS', 'BOIL', 'BOKS', 'BOOS', 'BOPS', 'BORS', 'BOSS', 'BOTS', 'BOWS', 'BOYS', 'BRIS', 'KOIS', 'POIS']
# BOKE ['BAKE', 'BIKE', 'BODE', 'BOKO', 'BOKS', 'BOLE', 'BONE', 'BORE', 'BUKE', 'BYKE', 'COKE', 'HOKE', 'JOKE', 'LOKE', 'MOKE', 'POKE', 'ROKE', 'SOKE', 'TOKE', 'WOKE', 'YOKE']
# BOKO ['BOHO', 'BOKE', 'BOKS', 'BOLO', 'BOYO', 'BOZO', 'MOKO', 'TOKO']
# BOKS ['BOAS', 'BOBS', 'BODS', 'BOGS', 'BOHS', 'BOIS', 'BOKE', 'BOKO', 'BOOS', 'BOPS', 'BORS', 'BOSS', 'BOTS', 'BOWS', 'BOYS', 'ROKS', 'WOKS', 'YOKS']
# BOLA ['BOBA', 'BOLD', 'BOLE', 'BOLL', 'BOLO', 'BOLT', 'BOMA', 'BONA', 'BORA', 'BOTA', 'COLA', 'KOLA', 'MOLA', 'SOLA', 'TOLA', 'VOLA']
# BOLD ['BALD', 'BOLA', 'BOLE', 'BOLL', 'BOLO', 'BOLT', 'BOND', 'BORD', 'COLD', 'FOLD', 'GOLD', 'HOLD', 'MOLD', 'SOLD', 'TOLD', 'WOLD', 'YOLD']
# BOLE ['BALE', 'BILE', 'BODE', 'BOKE', 'BOLA', 'BOLD', 'BOLL', 'BOLO', 'BOLT', 'BONE', 'BORE', 'COLE', 'DOLE', 'GOLE', 'HOLE', 'JOLE', 'MOLE', 'NOLE', 'POLE', 'ROLE', 'SOLE', 'TOLE', 'VOLE']
# BOLL ['BALL', 'BELL', 'BILL', 'BOIL', 'BOLA', 'BOLD', 'BOLE', 'BOLO', 'BOLT', 'BOOL', 'BOWL', 'BULL', 'COLL', 'DOLL', 'JOLL', 'LOLL', 'MOLL', 'NOLL', 'POLL', 'ROLL', 'TOLL']
# BOLO ['BOHO', 'BOKO', 'BOLA', 'BOLD', 'BOLE', 'BOLL', 'BOLT', 'BOYO', 'BOZO', 'KOLO', 'NOLO', 'POLO', 'SOLO']
# BOLT ['BELT', 'BOAT', 'BOET', 'BOLA', 'BOLD', 'BOLE', 'BOLL', 'BOLO', 'BOOT', 'BORT', 'BOTT', 'BOUT', 'COLT', 'DOLT', 'HOLT', 'JOLT', 'MOLT', 'POLT', 'TOLT', 'VOLT']
# BOMA ['BEMA', 'BIMA', 'BOBA', 'BOLA', 'BOMB', 'BONA', 'BORA', 'BOTA', 'COMA', 'HOMA', 'LOMA', 'NOMA', 'ROMA', 'SOMA']
# BOMB ['BOAB', 'BOMA', 'BOOB', 'COMB', 'TOMB', 'WOMB']
# BONA ['BOBA', 'BOLA', 'BOMA', 'BOND', 'BONE', 'BONG', 'BONK', 'BONY', 'BORA', 'BOTA', 'BUNA', 'DONA', 'MONA', 'NONA', 'ZONA']
# BOND ['BAND', 'BEND', 'BIND', 'BOLD', 'BONA', 'BONE', 'BONG', 'BONK', 'BONY', 'BORD', 'BUND', 'COND', 'FOND', 'HOND', 'KOND', 'POND', 'YOND']
# BONE ['BANE', 'BENE', 'BINE', 'BODE', 'BOKE', 'BOLE', 'BONA', 'BOND', 'BONG', 'BONK', 'BONY', 'BORE', 'CONE', 'DONE', 'FONE', 'GONE', 'HONE', 'LONE', 'NONE', 'PONE', 'RONE', 'SONE', 'TONE', 'ZONE']
# BONG ['BANG', 'BING', 'BONA', 'BOND', 'BONE', 'BONK', 'BONY', 'BOYG', 'BUNG', 'DONG', 'GONG', 'HONG', 'JONG', 'LONG', 'MONG', 'NONG', 'PONG', 'RONG', 'SONG', 'TONG']
# BONK ['BANK', 'BINK', 'BOAK', 'BOCK', 'BONA', 'BOND', 'BONE', 'BONG', 'BONY', 'BOOK', 'BORK', 'BOSK', 'BOUK', 'BUNK', 'CONK', 'GONK', 'HONK', 'KONK', 'MONK', 'PONK', 'TONK', 'WONK', 'ZONK']
# BONY ['BODY', 'BOGY', 'BONA', 'BOND', 'BONE', 'BONG', 'BONK', 'BOXY', 'CONY', 'MONY', 'PONY', 'TONY']
# BOOB ['BLOB', 'BOAB', 'BOMB', 'BOOH', 'BOOK', 'BOOL', 'BOOM', 'BOON', 'BOOR', 'BOOS', 'BOOT', 'DOOB']
# BOOH ['BOOB', 'BOOK', 'BOOL', 'BOOM', 'BOON', 'BOOR', 'BOOS', 'BOOT', 'BOSH', 'BOTH', 'POOH']
# BOOK ['BOAK', 'BOCK', 'BONK', 'BOOB', 'BOOH', 'BOOL', 'BOOM', 'BOON', 'BOOR', 'BOOS', 'BOOT', 'BORK', 'BOSK', 'BOUK', 'COOK', 'DOOK', 'GOOK', 'HOOK', 'JOOK', 'KOOK', 'LOOK', 'MOOK', 'NOOK', 'POOK', 'ROOK', 'SOOK', 'TOOK']
# BOOL ['BOIL', 'BOLL', 'BOOB', 'BOOH', 'BOOK', 'BOOM', 'BOON', 'BOOR', 'BOOS', 'BOOT', 'BOWL', 'COOL', 'DOOL', 'FOOL', 'GOOL', 'MOOL', 'POOL', 'SOOL', 'TOOL', 'WOOL']
# BOOM ['BOOB', 'BOOH', 'BOOK', 'BOOL', 'BOON', 'BOOR', 'BOOS', 'BOOT', 'BORM', 'COOM', 'DOOM', 'LOOM', 'ROOM', 'SOOM', 'TOOM', 'ZOOM']
# BOON ['BOOB', 'BOOH', 'BOOK', 'BOOL', 'BOOM', 'BOOR', 'BOOS', 'BOOT', 'BORN', 'BOUN', 'COON', 'DOON', 'GOON', 'HOON', 'LOON', 'MOON', 'NOON', 'POON', 'ROON', 'SOON', 'TOON', 'WOON', 'ZOON']
# BOOR ['BOAR', 'BOOB', 'BOOH', 'BOOK', 'BOOL', 'BOOM', 'BOON', 'BOOS', 'BOOT', 'BOWR', 'DOOR', 'GOOR', 'LOOR', 'MOOR', 'POOR']
# BOOS ['BIOS', 'BOAS', 'BOBS', 'BODS', 'BOGS', 'BOHS', 'BOIS', 'BOKS', 'BOOB', 'BOOH', 'BOOK', 'BOOL', 'BOOM', 'BOON', 'BOOR', 'BOOT', 'BOPS', 'BORS', 'BOSS', 'BOTS', 'BOWS', 'BOYS', 'BROS', 'COOS', 'DOOS', 'GOOS', 'LOOS', 'MOOS', 'POOS', 'ROOS', 'WOOS', 'ZOOS']
# BOOT ['BLOT', 'BOAT', 'BOET', 'BOLT', 'BOOB', 'BOOH', 'BOOK', 'BOOL', 'BOOM', 'BOON', 'BOOR', 'BOOS', 'BORT', 'BOTT', 'BOUT', 'COOT', 'FOOT', 'HOOT', 'LOOT', 'MOOT', 'POOT', 'ROOT', 'SOOT', 'TOOT', 'WOOT', 'ZOOT']
# BOPS ['BAPS', 'BOAS', 'BOBS', 'BODS', 'BOGS', 'BOHS', 'BOIS', 'BOKS', 'BOOS', 'BORS', 'BOSS', 'BOTS', 'BOWS', 'BOYS', 'COPS', 'DOPS', 'FOPS', 'HOPS', 'KOPS', 'LOPS', 'MOPS', 'OOPS', 'POPS', 'SOPS', 'TOPS', 'WOPS']
# BORA ['BOBA', 'BOLA', 'BOMA', 'BONA', 'BORD', 'BORE', 'BORK', 'BORM', 'BORN', 'BORS', 'BORT', 'BOTA', 'BURA', 'FORA', 'GORA', 'HORA', 'KORA', 'MORA', 'SORA', 'TORA']
# BORD ['BARD', 'BIRD', 'BOLD', 'BOND', 'BORA', 'BORE', 'BORK', 'BORM', 'BORN', 'BORS', 'BORT', 'BURD', 'CORD', 'FORD', 'LORD', 'SORD', 'WORD']
# BORE ['BARE', 'BERE', 'BODE', 'BOKE', 'BOLE', 'BONE', 'BORA', 'BORD', 'BORK', 'BORM', 'BORN', 'BORS', 'BORT', 'BYRE', 'CORE', 'DORE', 'FORE', 'GORE', 'HORE', 'KORE', 'LORE', 'MORE', 'PORE', 'RORE', 'SORE', 'TORE', 'WORE', 'YORE']
# BORK ['BARK', 'BERK', 'BIRK', 'BOAK', 'BOCK', 'BONK', 'BOOK', 'BORA', 'BORD', 'BORE', 'BORM', 'BORN', 'BORS', 'BORT', 'BOSK', 'BOUK', 'BURK', 'CORK', 'DORK', 'FORK', 'NORK', 'PORK', 'WORK', 'YORK']
# BORM ['BARM', 'BERM', 'BOOM', 'BORA', 'BORD', 'BORE', 'BORK', 'BORN', 'BORS', 'BORT', 'CORM', 'DORM', 'FORM', 'GORM', 'NORM', 'WORM']
# BORN ['BARN', 'BOON', 'BORA', 'BORD', 'BORE', 'BORK', 'BORM', 'BORS', 'BORT', 'BOUN', 'BURN', 'CORN', 'HORN', 'LORN', 'MORN', 'PORN', 'SORN', 'TORN', 'WORN']
# BORS ['BARS', 'BOAS', 'BOBS', 'BODS', 'BOGS', 'BOHS', 'BOIS', 'BOKS', 'BOOS', 'BOPS', 'BORA', 'BORD', 'BORE', 'BORK', 'BORM', 'BORN', 'BORT', 'BOSS', 'BOTS', 'BOWS', 'BOYS', 'BURS', 'CORS', 'DORS', 'HORS', 'JORS', 'KORS', 'MORS', 'TORS', 'VORS']
# BORT ['BOAT', 'BOET', 'BOLT', 'BOOT', 'BORA', 'BORD', 'BORE', 'BORK', 'BORM', 'BORN', 'BORS', 'BOTT', 'BOUT', 'DORT', 'FORT', 'MORT', 'PORT', 'RORT', 'SORT', 'TORT', 'WORT']
# BOSH ['BASH', 'BISH', 'BOOH', 'BOSK', 'BOSS', 'BOTH', 'BUSH', 'COSH', 'DOSH', 'GOSH', 'JOSH', 'LOSH', 'MOSH', 'NOSH', 'POSH', 'TOSH']
# BOSK ['BASK', 'BISK', 'BOAK', 'BOCK', 'BONK', 'BOOK', 'BORK', 'BOSH', 'BOSS', 'BOUK', 'BUSK', 'MOSK']
# BOSS ['BASS', 'BOAS', 'BOBS', 'BODS', 'BOGS', 'BOHS', 'BOIS', 'BOKS', 'BOOS', 'BOPS', 'BORS', 'BOSH', 'BOSK', 'BOTS', 'BOWS', 'BOYS', 'BUSS', 'COSS', 'DOSS', 'FOSS', 'GOSS', 'HOSS', 'JOSS', 'KOSS', 'LOSS', 'MOSS', 'POSS', 'SOSS', 'TOSS']
# BOTA ['BETA', 'BOBA', 'BOLA', 'BOMA', 'BONA', 'BORA', 'BOTH', 'BOTS', 'BOTT', 'IOTA', 'JOTA', 'LOTA', 'NOTA', 'ROTA']
# BOTH ['BATH', 'BETH', 'BOOH', 'BOSH', 'BOTA', 'BOTS', 'BOTT', 'COTH', 'DOTH', 'GOTH', 'LOTH', 'MOTH', 'SOTH']
# ...
# WUDU ['KUDU', 'PUDU', 'WUDS']
# WULL ['BULL', 'CULL', 'DULL', 'FULL', 'GULL', 'HULL', 'LULL', 'MULL', 'NULL', 'PULL', 'WALL', 'WELL', 'WILL']
# WUSS ['BUSS', 'CUSS', 'FUSS', 'HUSS', 'MUSS', 'PUSS', 'SUSS', 'WISS', 'WUDS']
# WYCH ['LYCH', 'WICH']
# WYES ['AYES', 'BYES', 'DYES', 'EYES', 'HYES', 'KYES', 'LYES', 'NYES', 'OYES', 'PYES', 'RYES', 'SYES', 'TYES', 'WAES', 'WEES', 'WOES', 'WYNS']
# WYLE ['FYLE', 'HYLE', 'KYLE', 'WALE', 'WILE', 'WYTE']
# WYND ['KYND', 'RYND', 'SYND', 'TYND', 'WAND', 'WEND', 'WIND', 'WYNN', 'WYNS']
# WYNN ['WINN', 'WYND', 'WYNS']
# WYNS ['WANS', 'WENS', 'WINS', 'WONS', 'WYES', 'WYND', 'WYNN']
# WYTE ['BYTE', 'CYTE', 'GYTE', 'HYTE', 'KYTE', 'LYTE', 'TYTE', 'WATE', 'WITE', 'WYLE']
# XYST ['CYST']
# YAAR ['HAAR', 'MAAR', 'YARR', 'YEAR']
# YABA ['BABA', 'CABA']
# YACK ['BACK', 'DACK', 'HACK', 'JACK', 'LACK', 'MACK', 'PACK', 'RACK', 'SACK', 'TACK', 'WACK', 'YANK', 'YARK', 'YOCK', 'YUCK', 'ZACK']
# YADS ['BADS', 'CADS', 'DADS', 'FADS', 'GADS', 'HADS', 'LADS', 'MADS', 'NADS', 'PADS', 'RADS', 'SADS', 'TADS', 'WADS', 'YAGS', 'YAHS', 'YAKS', 'YAMS', 'YAPS', 'YAWS', 'YAYS', 'YIDS', 'YODS']
# YAFF ['BAFF', 'CAFF', 'DAFF', 'FAFF', 'GAFF', 'HAFF', 'NAFF', 'RAFF', 'WAFF']
# YAGI ['MAGI', 'RAGI', 'VAGI', 'YAGS', 'YOGI']
# YAGS ['BAGS', 'CAGS', 'DAGS', 'FAGS', 'GAGS', 'HAGS', 'JAGS', 'LAGS', 'MAGS', 'NAGS', 'RAGS', 'SAGS', 'TAGS', 'VAGS', 'WAGS', 'YADS', 'YAGI', 'YAHS', 'YAKS', 'YAMS', 'YAPS', 'YAWS', 'YAYS', 'YUGS', 'ZAGS']
# YAHS ['AAHS', 'DAHS', 'FAHS', 'HAHS', 'LAHS', 'PAHS', 'RAHS', 'YADS', 'YAGS', 'YAKS', 'YAMS', 'YAPS', 'YAWS', 'YAYS']
# YAKS ['DAKS', 'JAKS', 'KAKS', 'MAKS', 'OAKS', 'TAKS', 'YADS', 'YAGS', 'YAHS', 'YAMS', 'YAPS', 'YAWS', 'YAYS', 'YOKS', 'YUKS']
# YALD ['BALD', 'WALD', 'YALE', 'YARD', 'YAUD', 'YELD', 'YOLD']
# YALE ['BALE', 'DALE', 'EALE', 'GALE', 'HALE', 'KALE', 'MALE', 'PALE', 'RALE', 'SALE', 'TALE', 'VALE', 'WALE', 'YALD', 'YARE', 'YATE', 'YULE']
# YAMS ['BAMS', 'CAMS', 'DAMS', 'GAMS', 'HAMS', 'JAMS', 'LAMS', 'MAMS', 'NAMS', 'PAMS', 'RAMS', 'SAMS', 'TAMS', 'YADS', 'YAGS', 'YAHS', 'YAKS', 'YAPS', 'YAWS', 'YAYS']
# YANG ['BANG', 'CANG', 'DANG', 'FANG', 'GANG', 'HANG', 'KANG', 'LANG', 'MANG', 'PANG', 'RANG', 'SANG', 'TANG', 'VANG', 'WANG', 'YANK']
# YANK ['BANK', 'DANK', 'FANK', 'HANK', 'LANK', 'RANK', 'SANK', 'TANK', 'WANK', 'YACK', 'YANG', 'YARK']
# YAPP ['YAPS', 'YAUP', 'YAWP']
# YAPS ['BAPS', 'CAPS', 'DAPS', 'GAPS', 'HAPS', 'JAPS', 'LAPS', 'MAPS', 'NAPS', 'PAPS', 'RAPS', 'SAPS', 'TAPS', 'WAPS', 'YADS', 'YAGS', 'YAHS', 'YAKS', 'YAMS', 'YAPP', 'YAWS', 'YAYS', 'YEPS', 'YIPS', 'YUPS', 'ZAPS']
# YARD ['BARD', 'CARD', 'EARD', 'FARD', 'HARD', 'LARD', 'MARD', 'NARD', 'PARD', 'SARD', 'WARD', 'YALD', 'YARE', 'YARK', 'YARN', 'YARR', 'YAUD', 'YERD', 'YIRD']
# YARE ['BARE', 'CARE', 'DARE', 'FARE', 'GARE', 'HARE', 'LARE', 'MARE', 'NARE', 'PARE', 'RARE', 'TARE', 'VARE', 'WARE', 'YALE', 'YARD', 'YARK', 'YARN', 'YARR', 'YATE', 'YORE']
# YARK ['BARK', 'CARK', 'DARK', 'HARK', 'JARK', 'KARK', 'LARK', 'MARK', 'NARK', 'PARK', 'RARK', 'SARK', 'WARK', 'YACK', 'YANK', 'YARD', 'YARE', 'YARN', 'YARR', 'YERK', 'YIRK', 'YORK']
# YARN ['BARN', 'CARN', 'DARN', 'EARN', 'HARN', 'KARN', 'LARN', 'TARN', 'WARN', 'YARD', 'YARE', 'YARK', 'YARR', 'YAWN']
# YARR ['CARR', 'PARR', 'YAAR', 'YARD', 'YARE', 'YARK', 'YARN', 'YIRR']
# YATE ['BATE', 'CATE', 'DATE', 'FATE', 'GATE', 'HATE', 'LATE', 'MATE', 'PATE', 'RATE', 'SATE', 'TATE', 'WATE', 'YALE', 'YARE', 'YITE']
# YAUD ['BAUD', 'DAUD', 'GAUD', 'HAUD', 'LAUD', 'MAUD', 'YALD', 'YARD', 'YAUP']
# YAUP ['CAUP', 'GAUP', 'JAUP', 'YAPP', 'YAUD', 'YAWP']
# YAWL ['BAWL', 'PAWL', 'WAWL', 'YAWN', 'YAWP', 'YAWS', 'YAWY', 'YOWL']
# YAWN ['BAWN', 'DAWN', 'FAWN', 'LAWN', 'MAWN', 'PAWN', 'RAWN', 'SAWN', 'YARN', 'YAWL', 'YAWP', 'YAWS', 'YAWY']
# YAWP ['GAWP', 'YAPP', 'YAUP', 'YAWL', 'YAWN', 'YAWS', 'YAWY']
# YAWS ['CAWS', 'DAWS', 'FAWS', 'HAWS', 'JAWS', 'KAWS', 'LAWS', 'MAWS', 'PAWS', 'RAWS', 'SAWS', 'TAWS', 'VAWS', 'WAWS', 'YADS', 'YAGS', 'YAHS', 'YAKS', 'YAMS', 'YAPS', 'YAWL', 'YAWN', 'YAWP', 'YAWY', 'YAYS', 'YEWS', 'YOWS']
# YAWY ['YAWL', 'YAWN', 'YAWP', 'YAWS']
# YAYS ['BAYS', 'CAYS', 'DAYS', 'FAYS', 'GAYS', 'HAYS', 'JAYS', 'KAYS', 'LAYS', 'MAYS', 'NAYS', 'PAYS', 'RAYS', 'SAYS', 'TAYS', 'WAYS', 'YADS', 'YAGS', 'YAHS', 'YAKS', 'YAMS', 'YAPS', 'YAWS']
# YBET ['ABET']
# YEAD ['BEAD', 'DEAD', 'HEAD', 'LEAD', 'MEAD', 'READ', 'TEAD', 'YEAH', 'YEAN', 'YEAR', 'YEAS', 'YEED', 'YELD', 'YERD']
# YEAH ['YEAD', 'YEAN', 'YEAR', 'YEAS', 'YECH']
# YEAN ['BEAN', 'DEAN', 'GEAN', 'JEAN', 'LEAN', 'MEAN', 'PEAN', 'REAN', 'SEAN', 'WEAN', 'YEAD', 'YEAH', 'YEAR', 'YEAS', 'YUAN']
# YEAR ['BEAR', 'DEAR', 'FEAR', 'GEAR', 'HEAR', 'LEAR', 'NEAR', 'PEAR', 'REAR', 'SEAR', 'TEAR', 'WEAR', 'YAAR', 'YEAD', 'YEAH', 'YEAN', 'YEAS']
# YEAS ['CEAS', 'KEAS', 'LEAS', 'PEAS', 'SEAS', 'TEAS', 'YEAD', 'YEAH', 'YEAN', 'YEAR', 'YENS', 'YEPS', 'YEWS', 'ZEAS']
# YEBO []
# YECH ['EECH', 'HECH', 'LECH', 'PECH', 'SECH', 'TECH', 'YEAH', 'YUCH']
# YEDE ['BEDE', 'CEDE', 'REDE', 'YEVE', 'YODE']
# YEED ['DEED', 'FEED', 'GEED', 'HEED', 'JEED', 'LEED', 'MEED', 'NEED', 'PEED', 'REED', 'SEED', 'TEED', 'WEED', 'YEAD', 'YELD', 'YERD']
# YEGG ['TEGG']
# YELD ['GELD', 'HELD', 'MELD', 'SELD', 'TELD', 'VELD', 'WELD', 'YALD', 'YEAD', 'YEED', 'YELK', 'YELL', 'YELM', 'YELP', 'YELT', 'YERD', 'YOLD']
# YELK ['WELK', 'YELD', 'YELL', 'YELM', 'YELP', 'YELT', 'YERK', 'YESK', 'YEUK', 'YOLK']
# YELL ['BELL', 'CELL', 'DELL', 'FELL', 'HELL', 'JELL', 'KELL', 'MELL', 'PELL', 'SELL', 'TELL', 'VELL', 'WELL', 'YELD', 'YELK', 'YELM', 'YELP', 'YELT', 'YILL']
# YELM ['HELM', 'YELD', 'YELK', 'YELL', 'YELP', 'YELT']
# YELP ['HELP', 'KELP', 'YELD', 'YELK', 'YELL', 'YELM', 'YELT']
# YELT ['BELT', 'CELT', 'DELT', 'FELT', 'GELT', 'KELT', 'MELT', 'PELT', 'TELT', 'WELT', 'YELD', 'YELK', 'YELL', 'YELM', 'YELP', 'YEST', 'YETT']
# YENS ['BENS', 'CENS', 'DENS', 'FENS', 'GENS', 'HENS', 'KENS', 'LENS', 'PENS', 'RENS', 'SENS', 'TENS', 'WENS', 'YEAS', 'YEPS', 'YEWS', 'YINS']
# YEPS ['CEPS', 'HEPS', 'KEPS', 'LEPS', 'NEPS', 'PEPS', 'REPS', 'SEPS', 'YAPS', 'YEAS', 'YENS', 'YEWS', 'YIPS', 'YUPS', 'ZEPS']
# YERD ['HERD', 'NERD', 'VERD', 'YARD', 'YEAD', 'YEED', 'YELD', 'YERK', 'YIRD']
# YERK ['BERK', 'JERK', 'MERK', 'NERK', 'PERK', 'SERK', 'YARK', 'YELK', 'YERD', 'YESK', 'YEUK', 'YIRK', 'YORK', 'ZERK']
# YESK ['DESK', 'YELK', 'YERK', 'YEST', 'YEUK']
# YEST ['BEST', 'FEST', 'GEST', 'HEST', 'JEST', 'KEST', 'LEST', 'NEST', 'PEST', 'REST', 'TEST', 'VEST', 'WEST', 'YELT', 'YESK', 'YETT', 'ZEST']
# YETI ['YETT']
# YETT ['FETT', 'NETT', 'SETT', 'YELT', 'YEST', 'YETI']
# YEUK ['NEUK', 'YELK', 'YERK', 'YESK', 'YOUK']
# YEVE ['LEVE', 'MEVE', 'NEVE', 'YEDE']
# YEWS ['DEWS', 'HEWS', 'JEWS', 'MEWS', 'NEWS', 'PEWS', 'REWS', 'SEWS', 'TEWS', 'YAWS', 'YEAS', 'YENS', 'YEPS', 'YOWS']
# YGOE []
# YIDS ['AIDS', 'BIDS', 'CIDS', 'FIDS', 'GIDS', 'KIDS', 'LIDS', 'MIDS', 'NIDS', 'RIDS', 'TIDS', 'VIDS', 'YADS', 'YINS', 'YIPS', 'YODS']
# YIKE ['BIKE', 'DIKE', 'FIKE', 'HIKE', 'KIKE', 'LIKE', 'MIKE', 'PIKE', 'SIKE', 'TIKE', 'YIPE', 'YITE', 'YLKE', 'YOKE', 'YUKE']
# YILL ['BILL', 'CILL', 'DILL', 'FILL', 'GILL', 'HILL', 'JILL', 'KILL', 'LILL', 'MILL', 'NILL', 'PILL', 'RILL', 'SILL', 'TILL', 'VILL', 'WILL', 'YELL', 'ZILL']
# YINS ['AINS', 'BINS', 'DINS', 'FINS', 'GINS', 'HINS', 'JINS', 'KINS', 'LINS', 'PINS', 'RINS', 'SINS', 'TINS', 'VINS', 'WINS', 'YENS', 'YIDS', 'YIPS', 'ZINS']
# YIPE ['KIPE', 'LIPE', 'PIPE', 'RIPE', 'SIPE', 'WIPE', 'YIKE', 'YIPS', 'YITE', 'YMPE']
# YIPS ['DIPS', 'GIPS', 'HIPS', 'KIPS', 'LIPS', 'MIPS', 'NIPS', 'PIPS', 'RIPS', 'SIPS', 'TIPS', 'YAPS', 'YEPS', 'YIDS', 'YINS', 'YIPE', 'YUPS', 'ZIPS']
# YIRD ['BIRD', 'GIRD', 'JIRD', 'YARD', 'YERD', 'YIRK', 'YIRR']
# YIRK ['BIRK', 'DIRK', 'FIRK', 'KIRK', 'LIRK', 'MIRK', 'YARK', 'YERK', 'YIRD', 'YIRR', 'YORK']
# YIRR ['BIRR', 'GIRR', 'TIRR', 'YARR', 'YIRD', 'YIRK']
# YITE ['BITE', 'CITE', 'DITE', 'GITE', 'KITE', 'LITE', 'MITE', 'NITE', 'RITE', 'SITE', 'TITE', 'VITE', 'WITE', 'YATE', 'YIKE', 'YIPE', 'ZITE']
# YLEM ['CLEM']
# YLKE ['YIKE', 'YOKE', 'YUKE']
# YMPE ['YIPE', 'YMPT']
# YMPT ['EMPT', 'YMPE']
# YOBS ['BOBS', 'COBS', 'DOBS', 'FOBS', 'GOBS', 'HOBS', 'JOBS', 'KOBS', 'LOBS', 'MOBS', 'NOBS', 'ROBS', 'SOBS', 'YODS', 'YOKS', 'YOUS', 'YOWS']
# YOCK ['BOCK', 'COCK', 'DOCK', 'HOCK', 'JOCK', 'LOCK', 'MOCK', 'NOCK', 'POCK', 'ROCK', 'SOCK', 'TOCK', 'WOCK', 'YACK', 'YOLK', 'YORK', 'YOUK', 'YUCK']
# YODE ['BODE', 'CODE', 'LODE', 'MODE', 'NODE', 'RODE', 'YEDE', 'YODH', 'YODS', 'YOKE', 'YORE', 'YOWE']
# YODH ['YODE', 'YODS', 'YOGH']
# YODS ['BODS', 'CODS', 'DODS', 'GODS', 'HODS', 'LODS', 'MODS', 'NODS', 'PODS', 'RODS', 'SODS', 'TODS', 'YADS', 'YIDS', 'YOBS', 'YODE', 'YODH', 'YOKS', 'YOUS', 'YOWS']
# YOGA ['TOGA', 'YOGH', 'YOGI', 'YUGA']
# YOGH ['HOGH', 'YODH', 'YOGA', 'YOGI']
# YOGI ['YAGI', 'YOGA', 'YOGH', 'YONI']
# YOKE ['BOKE', 'COKE', 'HOKE', 'JOKE', 'LOKE', 'MOKE', 'POKE', 'ROKE', 'SOKE', 'TOKE', 'WOKE', 'YIKE', 'YLKE', 'YODE', 'YOKS', 'YORE', 'YOWE', 'YUKE']
# YOKS ['BOKS', 'ROKS', 'WOKS', 'YAKS', 'YOBS', 'YODS', 'YOKE', 'YOUS', 'YOWS', 'YUKS']
# YOLD ['BOLD', 'COLD', 'FOLD', 'GOLD', 'HOLD', 'MOLD', 'SOLD', 'TOLD', 'WOLD', 'YALD', 'YELD', 'YOLK', 'YOND']
# YOLK ['FOLK', 'HOLK', 'POLK', 'VOLK', 'YELK', 'YOCK', 'YOLD', 'YORK', 'YOUK']
# YOMP ['COMP', 'POMP', 'ROMP', 'YOOP', 'YORP', 'YUMP']
# YOND ['BOND', 'COND', 'FOND', 'HOND', 'KOND', 'POND', 'YOLD', 'YONI', 'YONT']
# YONI ['CONI', 'NONI', 'YOGI', 'YOND', 'YONT']
# YONT ['FONT', 'OONT', 'PONT', 'RONT', 'WONT', 'YOND', 'YONI']
# YOOF ['COOF', 'GOOF', 'HOOF', 'LOOF', 'POOF', 'ROOF', 'WOOF', 'YOOP']
# YOOP ['COOP', 'GOOP', 'HOOP', 'LOOP', 'MOOP', 'NOOP', 'POOP', 'ROOP', 'SOOP', 'YOMP', 'YOOF', 'YORP']
# YORE ['BORE', 'CORE', 'DORE', 'FORE', 'GORE', 'HORE', 'KORE', 'LORE', 'MORE', 'PORE', 'RORE', 'SORE', 'TORE', 'WORE', 'YARE', 'YODE', 'YOKE', 'YORK', 'YORP', 'YOWE']
# YORK ['BORK', 'CORK', 'DORK', 'FORK', 'NORK', 'PORK', 'WORK', 'YARK', 'YERK', 'YIRK', 'YOCK', 'YOLK', 'YORE', 'YORP', 'YOUK']
# YORP ['DORP', 'GORP', 'YOMP', 'YOOP', 'YORE', 'YORK']
# YOUK ['BOUK', 'DOUK', 'GOUK', 'JOUK', 'POUK', 'SOUK', 'TOUK', 'YEUK', 'YOCK', 'YOLK', 'YORK', 'YOUR', 'YOUS', 'ZOUK']
# YOUR ['COUR', 'DOUR', 'FOUR', 'HOUR', 'JOUR', 'LOUR', 'POUR', 'SOUR', 'TOUR', 'YOUK', 'YOUS']
# YOUS ['FOUS', 'LOUS', 'MOUS', 'NOUS', 'SOUS', 'YOBS', 'YODS', 'YOKS', 'YOUK', 'YOUR', 'YOWS']
# YOWE ['HOWE', 'LOWE', 'YODE', 'YOKE', 'YORE', 'YOWL', 'YOWS']
# YOWL ['BOWL', 'COWL', 'DOWL', 'FOWL', 'GOWL', 'HOWL', 'JOWL', 'NOWL', 'SOWL', 'YAWL', 'YOWE', 'YOWS']
# YOWS ['BOWS', 'COWS', 'DOWS', 'HOWS', 'JOWS', 'KOWS', 'LOWS', 'MOWS', 'NOWS', 'POWS', 'ROWS', 'SOWS', 'TOWS', 'VOWS', 'WOWS', 'YAWS', 'YEWS', 'YOBS', 'YODS', 'YOKS', 'YOUS', 'YOWE', 'YOWL']
# YUAN ['DUAN', 'GUAN', 'TUAN', 'YEAN']
# YUCA ['YUCH', 'YUCK', 'YUGA']
# YUCH ['MUCH', 'OUCH', 'SUCH', 'YECH', 'YUCA', 'YUCK']
# YUCK ['BUCK', 'DUCK', 'FUCK', 'GUCK', 'HUCK', 'LUCK', 'MUCK', 'PUCK', 'RUCK', 'SUCK', 'TUCK', 'YACK', 'YOCK', 'YUCA', 'YUCH']
# YUFT ['TUFT', 'YURT']
# YUGA ['GUGA', 'JUGA', 'RUGA', 'YOGA', 'YUCA', 'YUGS']
# YUGS ['BUGS', 'DUGS', 'FUGS', 'HUGS', 'JUGS', 'LUGS', 'MUGS', 'PUGS', 'RUGS', 'TUGS', 'VUGS', 'YAGS', 'YUGA', 'YUKS', 'YUPS']
# YUKE ['BUKE', 'CUKE', 'DUKE', 'JUKE', 'LUKE', 'NUKE', 'PUKE', 'YIKE', 'YLKE', 'YOKE', 'YUKO', 'YUKS', 'YUKY', 'YULE']
# YUKO ['YUKE', 'YUKS', 'YUKY']
# YUKS ['AUKS', 'EUKS', 'OUKS', 'SUKS', 'YAKS', 'YOKS', 'YUGS', 'YUKE', 'YUKO', 'YUKY', 'YUPS']
# YUKY ['YUKE', 'YUKO', 'YUKS']
# YULE ['DULE', 'GULE', 'HULE', 'MULE', 'PULE', 'RULE', 'TULE', 'YALE', 'YUKE']
# YUMP ['BUMP', 'DUMP', 'GUMP', 'HUMP', 'JUMP', 'LUMP', 'MUMP', 'PUMP', 'RUMP', 'SUMP', 'TUMP', 'YOMP']
# YUNX []
# YUPS ['CUPS', 'DUPS', 'GUPS', 'HUPS', 'OUPS', 'PUPS', 'SUPS', 'TUPS', 'YAPS', 'YEPS', 'YIPS', 'YUGS', 'YUKS']
# YURT ['CURT', 'HURT', 'YUFT']
# YUTZ ['FUTZ', 'LUTZ', 'PUTZ']
# YUZU ['KUZU']
# YWIS ['IWIS']
# ZACK ['BACK', 'DACK', 'HACK', 'JACK', 'LACK', 'MACK', 'PACK', 'RACK', 'SACK', 'TACK', 'WACK', 'YACK']
# ZAGS ['BAGS', 'CAGS', 'DAGS', 'FAGS', 'GAGS', 'HAGS', 'JAGS', 'LAGS', 'MAGS', 'NAGS', 'RAGS', 'SAGS', 'TAGS', 'VAGS', 'WAGS', 'YAGS', 'ZAPS', 'ZIGS']
# ZANY ['CANY', 'MANY', 'WANY']
# ZAPS ['BAPS', 'CAPS', 'DAPS', 'GAPS', 'HAPS', 'JAPS', 'LAPS', 'MAPS', 'NAPS', 'PAPS', 'RAPS', 'SAPS', 'TAPS', 'WAPS', 'YAPS', 'ZAGS', 'ZEPS', 'ZIPS']
# ZARF ['BARF', 'ZURF']
# ZATI ['KATI', 'LATI', 'SATI', 'ZITI']
# ZEAL ['DEAL', 'FEAL', 'GEAL', 'HEAL', 'LEAL', 'MEAL', 'NEAL', 'PEAL', 'REAL', 'SEAL', 'TEAL', 'VEAL', 'WEAL', 'ZEAS']
# ZEAS ['CEAS', 'KEAS', 'LEAS', 'PEAS', 'SEAS', 'TEAS', 'YEAS', 'ZEAL', 'ZEDS', 'ZEES', 'ZEKS', 'ZELS', 'ZEPS']
# ZEBU ['ZOBU']
# ZEDS ['BEDS', 'FEDS', 'GEDS', 'KEDS', 'MEDS', 'NEDS', 'PEDS', 'REDS', 'TEDS', 'WEDS', 'ZEAS', 'ZEES', 'ZEKS', 'ZELS', 'ZEPS']
# ZEES ['BEES', 'CEES', 'DEES', 'FEES', 'GEES', 'JEES', 'LEES', 'MEES', 'PEES', 'REES', 'SEES', 'TEES', 'VEES', 'WEES', 'ZEAS', 'ZEDS', 'ZEKS', 'ZELS', 'ZEPS']
# ZEIN ['BEIN', 'MEIN', 'PEIN', 'REIN', 'VEIN']
# ZEKS ['KEKS', 'LEKS', 'NEKS', 'ZEAS', 'ZEDS', 'ZEES', 'ZELS', 'ZEPS']
# ZELS ['BELS', 'CELS', 'DELS', 'EELS', 'GELS', 'MELS', 'SELS', 'TELS', 'ZEAS', 'ZEDS', 'ZEES', 'ZEKS', 'ZEPS', 'ZOLS']
# ZEPS ['CEPS', 'HEPS', 'KEPS', 'LEPS', 'NEPS', 'PEPS', 'REPS', 'SEPS', 'YEPS', 'ZAPS', 'ZEAS', 'ZEDS', 'ZEES', 'ZEKS', 'ZELS', 'ZIPS']
# ZERK ['BERK', 'JERK', 'MERK', 'NERK', 'PERK', 'SERK', 'YERK', 'ZERO']
# ZERO ['AERO', 'CERO', 'DERO', 'HERO', 'KERO', 'WERO', 'ZERK']
# ZEST ['BEST', 'FEST', 'GEST', 'HEST', 'JEST', 'KEST', 'LEST', 'NEST', 'PEST', 'REST', 'TEST', 'VEST', 'WEST', 'YEST']
# ZETA ['BETA', 'FETA', 'GETA', 'KETA', 'META', 'SETA', 'WETA']
# ZEZE ['MEZE']
# ZHOS ['MHOS', 'OHOS', 'PHOS', 'RHOS', 'ZOOS']
# ZIFF ['BIFF', 'DIFF', 'JIFF', 'KIFF', 'MIFF', 'NIFF', 'RIFF', 'TIFF']
# ZIGS ['BIGS', 'CIGS', 'DIGS', 'FIGS', 'GIGS', 'JIGS', 'LIGS', 'MIGS', 'PIGS', 'RIGS', 'TIGS', 'VIGS', 'WIGS', 'ZAGS', 'ZINS', 'ZIPS', 'ZITS']
# ZILA ['FILA', 'GILA', 'HILA', 'PILA', 'ZILL']
# ZILL ['BILL', 'CILL', 'DILL', 'FILL', 'GILL', 'HILL', 'JILL', 'KILL', 'LILL', 'MILL', 'NILL', 'PILL', 'RILL', 'SILL', 'TILL', 'VILL', 'WILL', 'YILL', 'ZILA']
# ZIMB ['LIMB', 'NIMB']
# ZINC ['ZINE', 'ZING', 'ZINS']
# ZINE ['AINE', 'BINE', 'CINE', 'DINE', 'EINE', 'FINE', 'KINE', 'LINE', 'MINE', 'NINE', 'PINE', 'RINE', 'SINE', 'TINE', 'VINE', 'WINE', 'ZINC', 'ZING', 'ZINS', 'ZITE', 'ZONE']
# ZING ['BING', 'DING', 'GING', 'HING', 'KING', 'LING', 'MING', 'PING', 'RING', 'SING', 'TING', 'WING', 'ZINC', 'ZINE', 'ZINS']
# ZINS ['AINS', 'BINS', 'DINS', 'FINS', 'GINS', 'HINS', 'JINS', 'KINS', 'LINS', 'PINS', 'RINS', 'SINS', 'TINS', 'VINS', 'WINS', 'YINS', 'ZIGS', 'ZINC', 'ZINE', 'ZING', 'ZIPS', 'ZITS']
# ZIPS ['DIPS', 'GIPS', 'HIPS', 'KIPS', 'LIPS', 'MIPS', 'NIPS', 'PIPS', 'RIPS', 'SIPS', 'TIPS', 'YIPS', 'ZAPS', 'ZEPS', 'ZIGS', 'ZINS', 'ZITS']
# ZITE ['BITE', 'CITE', 'DITE', 'GITE', 'KITE', 'LITE', 'MITE', 'NITE', 'RITE', 'SITE', 'TITE', 'VITE', 'WITE', 'YITE', 'ZINE', 'ZITI', 'ZITS']
# ZITI ['TITI', 'ZATI', 'ZITE', 'ZITS']
# ZITS ['AITS', 'BITS', 'CITS', 'DITS', 'FITS', 'GITS', 'HITS', 'KITS', 'LITS', 'NITS', 'PITS', 'RITS', 'SITS', 'TITS', 'WITS', 'ZIGS', 'ZINS', 'ZIPS', 'ZITE', 'ZITI']
# ZIZZ ['FIZZ', 'GIZZ', 'HIZZ', 'JIZZ', 'MIZZ', 'TIZZ']
# ZOBO ['GOBO', 'HOBO', 'KOBO', 'LOBO', 'ZOBU']
# ZOBU ['ZEBU', 'ZOBO']
# ZOEA ['TOEA', 'ZONA']
# ZOIC []
# ZOLS ['COLS', 'DOLS', 'HOLS', 'JOLS', 'MOLS', 'POLS', 'SOLS', 'VOLS', 'ZELS', 'ZOOS']
# ZONA ['BONA', 'DONA', 'MONA', 'NONA', 'ZOEA', 'ZONE', 'ZONK']
# ZONE ['BONE', 'CONE', 'DONE', 'FONE', 'GONE', 'HONE', 'LONE', 'NONE', 'PONE', 'RONE', 'SONE', 'TONE', 'ZINE', 'ZONA', 'ZONK']
# ZONK ['BONK', 'CONK', 'GONK', 'HONK', 'KONK', 'MONK', 'PONK', 'TONK', 'WONK', 'ZONA', 'ZONE', 'ZOUK']
# ZOOM ['BOOM', 'COOM', 'DOOM', 'LOOM', 'ROOM', 'SOOM', 'TOOM', 'ZOON', 'ZOOS', 'ZOOT']
# ZOON ['BOON', 'COON', 'DOON', 'GOON', 'HOON', 'LOON', 'MOON', 'NOON', 'POON', 'ROON', 'SOON', 'TOON', 'WOON', 'ZOOM', 'ZOOS', 'ZOOT']
# ZOOS ['BOOS', 'COOS', 'DOOS', 'GOOS', 'LOOS', 'MOOS', 'POOS', 'ROOS', 'WOOS', 'ZHOS', 'ZOLS', 'ZOOM', 'ZOON', 'ZOOT']
# ZOOT ['BOOT', 'COOT', 'FOOT', 'HOOT', 'LOOT', 'MOOT', 'POOT', 'ROOT', 'SOOT', 'TOOT', 'WOOT', 'ZOOM', 'ZOON', 'ZOOS']
# ZORI ['GORI', 'HORI', 'NORI', 'SORI', 'TORI']
# ZOUK ['BOUK', 'DOUK', 'GOUK', 'JOUK', 'POUK', 'SOUK', 'TOUK', 'YOUK', 'ZONK']
# ZULU ['LULU', 'PULU', 'SULU']
# ZUPA ['OUPA', 'PUPA']
# ZURF ['CURF', 'SURF', 'TURF', 'ZARF']
# ZYGA []
# ZYME ['CYME', 'LYME']
# ZZZS []

# %% [markdown]
# ### 3. Write the Graph to a file
# * to make this graph super fast to load on demand, write the graph to a file (eg: 4_letter_graph.txt) with the first word on the line being the KEY, and the rest of the words being the list of VALUES, all separated by spaces. eg:
#
# > DEAD BEAD DEAF DEAL DEAN DEAR DEAW DEED DEID DRAD DUAD DYAD HEAD LEAD MEAD READ TEAD YEAD
# > DEAF DEAD DEAL DEAN DEAR DEAW DEIF DELF LEAF
#
# Here's a reminder on how to write to a file in Python in case you're rusty on this:
#
# ```python
#
# # write the 2 letter words to a new file called "words2.txt"
# with open("words2.txt","w") as file:
#     for word in words2:
#         file.write(f"{word}\n")
#     ```

# %%
def write_to_file(l):
    '''
    only need to tell the program how long you the words to be
    input: word length
    output: none, but writes/createsa file
    '''
    d = create_dictionary_graph(l)
    with open(f'{l}_letter_graph.txt', 'w') as file:
        for w in d:
            file.write(f"{w}")
            for w_ in d[w]:
                file.write(f" {w_}")
            # for formatting
            file.write("\n")
    print(f'done for {l}')

# %%
write_to_file(4)
# Out:
# 0.09167583425009168
# 0.18335166850018336
# 0.27502750275027504
# 0.3667033370003667
# 0.4583791712504584
# 0.5500550055005501
# 0.6417308397506417
# 0.7334066740007334
# 0.8250825082508251
# 0.9167583425009168
# done for 4

# %% [markdown]
# ### 4. Repeat steps 2 and 3 so you have files for 4, 5, 6 and 7 letter words at least

# %%
for i in range(5, 8):
    write_to_file(i)
# Out:
# 0.04007052412245552
# 0.08014104824491104
# 0.12021157236736657
# 0.16028209648982208
# 0.2003526206122776
# 0.24042314473473314
# 0.2804936688571886
# 0.32056419297964417
# 0.3606347171020997
# 0.4007052412245552
# 0.44077576534701074
# 0.4808462894694663
# 0.5209168135919218
# 0.5609873377143773
# 0.6010578618368329
# 0.6411283859592883
# 0.6811989100817438
# 0.7212694342041994
# 0.7613399583266549
# 0.8014104824491104
# 0.841481006571566
# 0.8815515306940215
# 0.921622054816477
# 0.9616925789389326
# done for 5
# 0.022566231890598906
# 0.04513246378119781
# 0.06769869567179672
# 0.09026492756239562
# 0.11283115945299454
# 0.13539739134359344
# 0.15796362323419236
# 0.18052985512479125
# 0.20309608701539017
# 0.2256623189059891
# 0.24822855079658798
# 0.2707947826871869
# 0.2933610145777858
# 0.3159272464683847
# 0.33849347835898363
# 0.3610597102495825
# 0.3836259421401814
# 0.40619217403078034
# 0.42875840592137926
# 0.4513246378119782
# 0.47389086970257704
# 0.49645710159317596
# 0.5190233334837748
# 0.5415895653743737
# 0.5641557972649727
# 0.5867220291555716
# 0.6092882610461705
# 0.6318544929367694
# 0.6544207248273683
# 0.6769869567179673
# 0.6995531886085662
# 0.722119420499165
# 0.7446856523897639
# 0.7672518842803628
# 0.7898181161709618
# 0.8123843480615607
# 0.8349505799521596
# 0.8575168118427585
# 0.8800830437333574
# 0.9026492756239564
# 0.9252155075145552
# 0.9477817394051541
# 0.970347971295753
# 0.9929142031863519
# done for 6
# 0.015193412136497615
# 0.03038682427299523
# 0.045580236409492846
# 0.06077364854599046
# 0.07596706068248807
# 0.09116047281898569
# 0.1063538849554833
# 0.12154729709198092
# 0.13674070922847853
# 0.15193412136497614
# 0.16712753350147377
# 0.18232094563797138
# 0.197514357774469
# 0.2127077699109666
# 0.2279011820474642
# 0.24309459418396184
# 0.25828800632045945
# 0.27348141845695706
# 0.28867483059345467
# 0.3038682427299523
# 0.3190616548664499
# 0.33425506700294755
# 0.34944847913944516
# 0.36464189127594276
# 0.3798353034124404
# 0.395028715548938
# 0.4102221276854356
# 0.4254155398219332
# 0.4406089519584308
# 0.4558023640949284
# 0.4709957762314261
# 0.4861891883679237
# 0.5013826005044213
# 0.5165760126409189
# 0.5317694247774165
# 0.5469628369139141
# 0.5621562490504117
# 0.5773496611869093
# 0.5925430733234069
# 0.6077364854599046
# 0.6229298975964022
# 0.6381233097328998
# 0.6533167218693974
# 0.6685101340058951
# 0.6837035461423927
# 0.6988969582788903
# 0.7140903704153879
# 0.7292837825518855
# 0.7444771946883831
# 0.7596706068248807
# 0.7748640189613784
# 0.790057431097876
# 0.8052508432343736
# 0.8204442553708712
# 0.8356376675073688
# 0.8508310796438664
# 0.866024491780364
# 0.8812179039168616
# 0.8964113160533592
# 0.9116047281898568
# 0.9267981403263545
# 0.9419915524628522
# 0.9571849645993498
# 0.9723783767358474
# 0.987571788872345
# done for 7

# %% [markdown]
# ### 5. Write a function that allows you to quickly load the file into an Adjacency List dictionary

# %%
# Function to load a text file into an adjecency list graph in the form of a dictionary

def load_graph(file = "4_letter_graph.txt"):
    '''
    Reads a file in and returns a graph in the form of an adjacency list dictionary
    inputs: file name
    outputs: the adjacency list dictionary
    '''
    letter_dict = {}
    with open(file, 'r') as f:
        for line in f:
            # make line a list and split the list into 2
            letter_dict[line.split()[0]] = line.split()[1::]
    return letter_dict


for length in range(4, 8):
    exec(f"letter_graph_{length} = load_graph('{length}_letter_graph.txt')")

print(letter_graph_4)
# Out:
# WARNING: Some output was deleted.

# %% [markdown]
# ### Day 2:  Breadth First Search (DFS) to Defeat Word Golf
#
# Paste instructions for Day 2 here after they have been delivered (after class lecture on Breadth First Search)
